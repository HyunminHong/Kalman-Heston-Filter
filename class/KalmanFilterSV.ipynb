# %%
import sys
from pathlib import Path

current_dir = Path().resolve()
parent_dir = current_dir.parent
sys.path.insert(0, str(parent_dir))

from KalmanFilterSV import MeasurementType, HestonKalmanFilter
from model.Heston import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set initial conditions and simulation parameters
S0 = 100
V0 = 0.04
params = {
    'mu': 0.05,
    'rho': -0.8,
    'kappa': 0.8,
    'theta': 0.04,
    'xi': 0.2
}
std_asy = np.sqrt(params['theta'] * params['xi']**2 / (2 * params['kappa']))
assert 2 * params['kappa'] * params['theta'] > params['xi']**2, "Feller condition is violated!"

Hest = Heston(**params)
time_daily, S_daily, daily_returns, daily_true_V, daily_RV = Hest.path_simulation(
    S0, V0, T_years=10, trading_days=252, intraday_intervals=39, seed=10
)
R_daily = daily_returns.copy()

# %%
burnin = 100
dt = 1  # Daily

# ============================================================================
# 1. BOTH Measurements: Uses both returns and RV
# ============================================================================

# Instantiate the Kalman filter for BOTH measurement type.
hkf_both = HestonKalmanFilter(measurement_type=MeasurementType.BOTH, dt=dt, V0=0.01, P0=0.1)
# Set the full data: filtering will be computed over all observations.
hkf_both.set_data(returns=R_daily, rv=daily_RV)
# For BOTH, parameter order is: [kappa, theta, xi, mu, sigma]
initial_params_both = np.array([0.001, 0.001, 0.001, 0.001, 0.001])
# Fit the model using the burnin (likelihood uses only t ≥ burnin).
fit_results_both = hkf_both.fit(initial_params=initial_params_both, burnin=burnin)
params_opt_both = fit_results_both['params']
print("Optimized parameters (BOTH):", params_opt_both)
# Retrieve filtered variance.
V_filt_both = hkf_both.get_filtered_variance()

# ============================================================================
# 2. RETURNS Measurement: Uses only returns data
# ============================================================================

hkf_returns = HestonKalmanFilter(measurement_type=MeasurementType.RETURNS, dt=dt, V0=0.01, P0=0.1)
# For returns-only, only return data is needed.
hkf_returns.set_data(returns=R_daily)
# Parameter order for RETURNS is: [kappa, theta, xi, mu]
initial_params_returns = np.array([0.001, 0.001, 0.001, 0.001])
fit_results_returns = hkf_returns.fit(initial_params=initial_params_returns, burnin=burnin)
params_opt_returns = fit_results_returns['params']
print("Optimized parameters (RETURNS):", params_opt_returns)
V_filt_returns = hkf_returns.get_filtered_variance()

# ============================================================================
# 3. RV Measurement: Uses only realized variance data
# ============================================================================

hkf_rv = HestonKalmanFilter(measurement_type=MeasurementType.RV, dt=dt, V0=0.01, P0=0.1)
# For RV-only, only the RV data is provided.
hkf_rv.set_data(rv=daily_RV)
# Parameter order for RV is: [kappa, theta, xi, sigma]
initial_params_rv = np.array([0.8, 0.01, 0.001, 0.5])
fit_results_rv = hkf_rv.fit(initial_params=initial_params_rv, burnin=burnin)
params_opt_rv = fit_results_rv['params']
print("Optimized parameters (RV):", params_opt_rv)
V_filt_rv = hkf_rv.get_filtered_variance()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.73181D+04    |proj g|=  2.01000D-01
#
# At iterate    1    f= -2.73210D+04    |proj g|=  2.00876D-01
#
# At iterate    2    f= -2.73716D+04    |proj g|=  2.99076D+04
#
# At iterate    3    f= -2.73806D+04    |proj g|=  2.00233D-01
#
# At iterate    4    f= -2.73821D+04    |proj g|=  1.36547D+04
#
# At iterate    5    f= -2.73828D+04    |proj g|=  4.06252D+03
#
# At iterate    6    f= -2.73832D+04    |proj g|=  1.11389D+03
#
# At iterate    7    f= -2.73835D+04    |proj g|=  2.00169D-01
#
# At iterate    8    f= -2.73835D+04    |proj g|=  1.99996D+00
#
# At iterate    9    f= -2.73835D+04    |proj g|=  1.28101D+01
#
# At iterate   10    f= -2.73835D+04    |proj g|=  2.43011D+02
#
# At iterate   11    f= -2.73835D+04    |proj g|=  5.05125D+02
#
# At iterate   12    f= -2.73835D+04    |proj g|=  9.94830D+02
#
# At iterate   13    f= -2.73835D+04    |proj g|=  1.90825D+03
#
# At iterate   14    f= -2.73835D+04    |proj g|=  2.04870D+03
#
# At iterate   15    f= -2.73835D+04    |proj g|=  1.31176D+03
#
# At iterate   16    f= -2.73835D+04    |proj g|=  9.99401D-01
#
# At iterate   17    f= -2.73835D+04    |proj g|=  3.54745D+02
#
# At iterate   18    f= -2.73835D+04    |proj g|=  5.03745D+02
#
# At iterate   19    f= -2.73835D+04    |proj g|=  5.13954D+02
#
# At iterate   20    f= -2.73835D+04    |proj g|=  2.11621D+02
#
# At iterate   21    f= -2.73835D+04    |proj g|=  3.99236D+02
#
# At iterate   22    f= -2.73835D+04    |proj g|=  1.70915D+02
#
# At iterate   23    f= -2.73835D+04    |proj g|=  3.53142D+01
#
# QMLE Results for Heston Model:
# At iterate   24    f= -2.73835D+04    |proj g|=  2.00168D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     24     30     31     0     0   2.002D-01  -2.738D+04
#   F =  -27383.513185026884
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# --------------------------------------------------
# kappa: 0.000799
# theta: 0.000203
# xi: 0.000737
# mu: 0.000168
# sigma: 0.000036
# Negative Log-Likelihood: -27383.513185
# Convergence: True
# --------------------------------------------------
# Optimized parameters (BOTH): [7.98818665e-04 2.02894025e-04 7.36746439e-04 1.68474955e-04
#  3.64833569e-05]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.75085D+03    |proj g|=  1.92895D+05
#
# At iterate    1    f= -4.20976D+03    |proj g|=  9.98999D-01
#
# At iterate    2    f= -4.75920D+03    |proj g|=  8.35596D+03
#
# At iterate    3    f= -4.82058D+03    |proj g|=  9.94391D-01
#   ys=-2.672E+01  -gs= 6.315E+02 BFGS update SKIPPED
#
# At iterate    4    f= -6.20506D+03    |proj g|=  1.26015D+08
#
# At iterate    5    f= -6.53767D+03    |proj g|=  9.90729D-01
#
# At iterate    6    f= -6.54193D+03    |proj g|=  9.90719D-01
#
# At iterate    7    f= -6.95660D+03    |proj g|=  1.26119D+04
#
# At iterate    8    f= -6.95857D+03    |proj g|=  9.90577D-01
#
# At iterate    9    f= -7.05391D+03    |proj g|=  2.20796D+04
#
# At iterate   10    f= -7.05457D+03    |proj g|=  8.21496D+03
#
# At iterate   11    f= -7.06362D+03    |proj g|=  2.28418D+04
#
# At iterate   12    f= -7.06610D+03    |proj g|=  2.53658D+04
#
# At iterate   13    f= -7.09356D+03    |proj g|=  9.90294D-01
#
# At iterate   14    f= -7.09444D+03    |proj g|=  9.90251D-01
#
# At iterate   15    f= -7.09879D+03    |proj g|=  4.72829D+05
#
# At iterate   16    f= -7.12147D+03    |proj g|=  9.88364D-01
#
# At iterate   17    f= -7.16536D+03    |proj g|=  3.45994D+05
#   ys=-3.571E+01  -gs= 4.111E+01 BFGS update SKIPPED
#
# At iterate   18    f= -7.16909D+03    |proj g|=  1.44096D+06
#
# At iterate   19    f= -7.17271D+03    |proj g|=  9.10767D+04
#
# At iterate   20    f= -7.18675D+03    |proj g|=  1.11641D+07
#
# At iterate   21    f= -7.18707D+03    |proj g|=  2.21891D+07
#   ys=-1.459E-01  -gs= 1.285E+00 BFGS update SKIPPED
#
# At iterate   22    f= -7.20861D+03    |proj g|=  3.85071D+04
#
# At iterate   23    f= -7.23817D+03    |proj g|=  1.59747D+06
#
# At iterate   24    f= -7.23908D+03    |proj g|=  3.32892D+06
#
# At iterate   25    f= -7.28209D+03    |proj g|=  5.70301D+03
#
# At iterate   26    f= -7.28459D+03    |proj g|=  5.95221D+03
#
# At iterate   27    f= -7.28555D+03    |proj g|=  7.82162D+04
#
# At iterate   28    f= -7.28687D+03    |proj g|=  5.34608D+04
#
# At iterate   29    f= -7.29888D+03    |proj g|=  5.45892D+03
#
# At iterate   30    f= -7.31230D+03    |proj g|=  8.30585D+03
#
# At iterate   31    f= -7.31644D+03    |proj g|=  8.35500D+04
#
# At iterate   32    f= -7.31907D+03    |proj g|=  1.31119D+05
#
# At iterate   33    f= -7.32165D+03    |proj g|=  1.82418D+05
#
# At iterate   34    f= -7.32557D+03    |proj g|=  2.37080D+05
#
# At iterate   35    f= -7.32797D+03    |proj g|=  1.99714D-01
#
# At iterate   36    f= -7.33058D+03    |proj g|=  1.17830D+03
#
# At iterate   37    f= -7.33108D+03    |proj g|=  2.99770D+04
#
# At iterate   38    f= -7.33117D+03    |proj g|=  7.91713D+02
#
# At iterate   39    f= -7.33121D+03    |proj g|=  9.59463D-01
#
# At iterate   40    f= -7.33125D+03    |proj g|=  1.79994D+04
#
# At iterate   41    f= -7.33133D+03    |proj g|=  5.48456D+04
#
# At iterate   42    f= -7.33138D+03    |proj g|=  4.50931D+04
#
# At iterate   43    f= -7.33140D+03    |proj g|=  1.40091D+04
#
# At iterate   44    f= -7.33140D+03    |proj g|=  1.75328D+03
#
# At iterate   45    f= -7.33140D+03    |proj g|=  1.45044D+02
#
# QMLE Results for Heston Model:
# --------------------------------------------------
# kappa: 0.042015
# theta: 0.000138
# xi: 0.010854
# mu: -0.000029
# Negative Log-Likelihood: -7331.400512
# Convergence: True
# --------------------------------------------------
# Optimized parameters (RETURNS): [ 4.20146814e-02  1.38237155e-04  1.08541089e-02 -2.92512244e-05]
#
# At iterate   46    f= -7.33140D+03    |proj g|=  2.05641D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     46    123     50     3     0   2.056D+01  -7.331D+03
#   F =  -7331.4005123803126
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.97669D+03    |proj g|=  2.45282D+00
#
# At iterate    1    f= -6.79307D+03    |proj g|=  2.64881D+02
#
# At iterate    2    f= -8.69739D+03    |proj g|=  8.64075D-01
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate    3    f= -8.97976D+03    |proj g|=  8.64062D-01
#
# At iterate    4    f= -1.74567D+04    |proj g|=  2.67391D-01
#   ys=-1.960E+06  -gs= 2.315E+03 BFGS update SKIPPED
#
# At iterate    5    f= -1.76026D+04    |proj g|=  9.40089D+03
#
# At iterate    6    f= -1.76877D+04    |proj g|=  4.36706D+03
#
# At iterate    7    f= -1.76891D+04    |proj g|=  7.60378D+01
#
# At iterate    8    f= -1.76894D+04    |proj g|=  9.28985D-01
#
# At iterate    9    f= -1.76894D+04    |proj g|=  1.69270D-01
#
# At iterate   10    f= -1.76894D+04    |proj g|=  1.69261D-01
#
# At iterate   11    f= -1.76894D+04    |proj g|=  1.69259D-01
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   12    f= -1.82957D+04    |proj g|=  7.77992D+06
#
# At iterate   13    f= -1.85581D+04    |proj g|=  1.43189D+07
#
# At iterate   14    f= -1.85714D+04    |proj g|=  1.64802D+07
#
# At iterate   15    f= -1.85727D+04    |proj g|=  1.67065D+07
#
# At iterate   16    f= -1.85845D+04    |proj g|=  1.78674D+07
#
# At iterate   17    f= -1.86094D+04    |proj g|=  1.91885D+07
#
# At iterate   18    f= -1.86779D+04    |proj g|=  2.04507D+07
#
# At iterate   19    f= -1.88152D+04    |proj g|=  1.69123D+07
#
# At iterate   20    f= -1.90716D+04    |proj g|=  1.91373D+02
#
# At iterate   21    f= -1.91583D+04    |proj g|=  3.30863D+06
#
# At iterate   22    f= -1.91583D+04    |proj g|=  3.31217D+06
#
# At iterate   23    f= -1.91695D+04    |proj g|=  3.79998D+06
#
# At iterate   24    f= -1.91876D+04    |proj g|=  4.61777D+06
#
# At iterate   25    f= -1.92001D+04    |proj g|=  4.02517D+06
#
# At iterate   26    f= -1.92332D+04    |proj g|=  3.32159D+05
#
# At iterate   27    f= -1.92336D+04    |proj g|=  3.14579D+03
#
# At iterate   28    f= -1.92336D+04    |proj g|=  2.61009D+03
#
# At iterate   29    f= -1.92337D+04    |proj g|=  2.10973D+03
#
# At iterate   30    f= -1.92339D+04    |proj g|=  1.24102D+03
#
# At iterate   31    f= -1.92343D+04    |proj g|=  9.24973D-01
#
# At iterate   32    f= -1.92356D+04    |proj g|=  9.23592D-01
#
# At iterate   33    f= -1.92388D+04    |proj g|=  9.19980D-01
#
# At iterate   34    f= -1.92470D+04    |proj g|=  9.10746D-01
#
# At iterate   35    f= -1.92690D+04    |proj g|=  8.86203D-01
#
# At iterate   36    f= -1.93315D+04    |proj g|=  8.17293D-01
#
# At iterate   37    f= -2.06630D+04    |proj g|=  4.67263D-03
#   ys=-2.727E+02  -gs= 8.766E+02 BFGS update SKIPPED
#
# At iterate   38    f= -2.11045D+04    |proj g|=  9.99998D-01
#
# At iterate   39    f= -2.13843D+04    |proj g|=  1.99846D+00
#
# At iterate   40    f= -2.15085D+04    |proj g|=  2.24733D-02
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   41    f= -2.16362D+04    |proj g|=  3.11747D-03
#
# At iterate   42    f= -2.16886D+04    |proj g|=  3.14382D-03
#
# At iterate   43    f= -2.17442D+04    |proj g|=  2.80587D-03
#
# At iterate   44    f= -2.17529D+04    |proj g|=  2.61678D-03
#
# At iterate   45    f= -2.17535D+04    |proj g|=  1.99739D+00
#
# At iterate   46    f= -2.17535D+04    |proj g|=  2.02204D+02
#
# At iterate   47    f= -2.17535D+04    |proj g|=  1.99739D+00
#
# QMLE Results for Heston Model:
# --------------------------------------------------
# kappa: 0.000001
# theta: 0.000157
# xi: 0.000778
# sigma: 0.002608
# Negative Log-Likelihood: -21753.456655
# Convergence: True
# --------------------------------------------------
# Optimized parameters (RV): [1.00000000e-06 1.56720552e-04 7.78005104e-04 2.60835890e-03]
#
# At iterate   48    f= -2.17535D+04    |proj g|=  3.81988D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     48     93     53     2     1   3.820D-01  -2.175D+04
#   F =  -21753.456654661772
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# ============================================================================
# Plotting the Filtering Results Side-by-Side
# ============================================================================
burnin = 1000

fig, axes = plt.subplots(3, 1, figsize=(18, 18))

# Subplot for BOTH measurements
axes[0].plot(time_daily[burnin:], daily_true_V[burnin:], label="True Integrated Variance", lw=2)
axes[0].plot(time_daily[burnin:], V_filt_both[burnin:], label="Filtered Volatility", lw=1)
axes[0].plot(time_daily[burnin:], daily_RV[burnin:], label="Realized Volatility", lw=0.3, linestyle="--")
axes[0].set_title("BOTH Measurements")
axes[0].set_xlabel("Time (years)")
axes[0].set_ylabel("Variance Level")
axes[0].legend(loc="upper right")

# Subplot for RETURNS measurement
axes[1].plot(time_daily[burnin:], daily_true_V[burnin:], label="True Integrated Variance", lw=2)
axes[1].plot(time_daily[burnin:], V_filt_returns[burnin:], label="Filtered Volatility", lw=1)
axes[1].plot(time_daily[burnin:], daily_RV[burnin:], label="Realized Volatility", lw=0.3, linestyle="--")
axes[1].set_title("RETURNS Measurement")
axes[1].set_xlabel("Time (years)")
axes[1].legend(loc="upper right")

# Subplot for RV measurement
axes[2].plot(time_daily[burnin:], daily_true_V[burnin:], label="True Integrated Variance", lw=2)
axes[2].plot(time_daily[burnin:], V_filt_rv[burnin:], label="Filtered Volatility", lw=1)
axes[2].plot(time_daily[burnin:], daily_RV[burnin:], label="Realized Volatility", lw=0.3, linestyle="--")
axes[2].set_title("RV Measurement")
axes[2].set_xlabel("Time (years)")
axes[2].legend(loc="upper right")

plt.tight_layout()
plt.show()

# ============================================================================
# Compute RMSE (Post Burnin)
# ============================================================================

true_post = daily_true_V[burnin:]
rmse_both = np.sqrt(np.mean((true_post - V_filt_both[burnin:]) ** 2))
rmse_returns = np.sqrt(np.mean((true_post - V_filt_returns[burnin:]) ** 2))
rmse_rv = np.sqrt(np.mean((true_post - V_filt_rv[burnin:]) ** 2))

print(f"RMSE (BOTH - Filtered vs True): {rmse_both:.6f}")
print(f"RMSE (RETURNS - Filtered vs True): {rmse_returns:.6f}")
print(f"RMSE (RV - Filtered vs True): {rmse_rv:.6f}")

# ============================================================================
# Print Model Summaries for Each Measurement Type
# ============================================================================

print("\n--- Model Summary: BOTH ---")
hkf_both.summary()

print("\n--- Model Summary: RETURNS ---")
hkf_returns.summary()

print("\n--- Model Summary: RV ---")
hkf_rv.summary()
# Out:
# RMSE (BOTH - Filtered vs True): 0.000025
# RMSE (RETURNS - Filtered vs True): 0.000089
# RMSE (RV - Filtered vs True): 0.000022
#
# --- Model Summary: BOTH ---
#
# Heston Kalman Filter Summary
# ==================================================
# Measurement Type: both
# Time Interval (dt): 1
# Initial Variance (V0): 0.010000
# Initial Covariance (P0): 0.100000
#
# Fitted Parameters:
# --------------------------------------------------
# kappa: 0.000799
# theta: 0.000203
# xi: 0.000737
# mu: 0.000168
# sigma: 0.000036
#
# Negative Log-Likelihood: -27383.513185
# Convergence: True
#
# AIC: -54757.026370
# BIC: -54727.868284
# ==================================================
#
# --- Model Summary: RETURNS ---
#
# Heston Kalman Filter Summary
# ==================================================
# Measurement Type: returns
# Time Interval (dt): 1
# Initial Variance (V0): 0.010000
# Initial Covariance (P0): 0.100000
#
# Fitted Parameters:
# --------------------------------------------------
# kappa: 0.042015
# theta: 0.000138
# xi: 0.010854
# mu: -0.000029
#
# Negative Log-Likelihood: -7331.400512
# Convergence: True
#
# AIC: -14654.801025
# BIC: -14631.474556
# ==================================================
#
# --- Model Summary: RV ---
#
# Heston Kalman Filter Summary
# ==================================================
# Measurement Type: realized_variance
# Time Interval (dt): 1
# Initial Variance (V0): 0.010000
# Initial Covariance (P0): 0.100000
#
# Fitted Parameters:
# --------------------------------------------------
# kappa: 0.000001
# theta: 0.000157
# xi: 0.000778
# sigma: 0.002608
#
# Negative Log-Likelihood: -21753.456655
# Convergence: True
#
# AIC: -43498.913309
# BIC: -43475.586840
# ==================================================

# %%
kappa: 1.215837
theta: 0.000148
xi: 0.000001
mu: 0.000027
sigma: 0.000001

# %%
-21700
