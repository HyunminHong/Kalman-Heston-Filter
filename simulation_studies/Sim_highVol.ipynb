# %%
cd ..
# Out:
# C:\Users\688228hh\Kalman-Heston-Filter

# %%
from src.Utility import Utility, MeasurementType
from src.KalmanFilterSV import HestonKalmanFilter
from src.KalmanFilterCorr import HestonKalmanFilterCorr
from src.ParticleFilter import PFHeston
from src.RealizedGARCH import RealizedGARCH
from src.Heston import *
from scipy.optimize import minimize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from arch import arch_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# Set initial conditions and simulation parameters
S0 = 100
V0 = 0.04
params = {
    'mu': 0.05,
    'rho': -0.8,
    'kappa': 11.0,
    'theta': 0.04,
    'xi': 0.9
}
std_asy = np.sqrt(params['theta'] * params['xi']**2 / (2 * params['kappa']))
feller_cond = 2 * params['kappa'] * params['theta'] / params['xi']**2
print(round(feller_cond, 2))
assert feller_cond > 1, "Feller condition is violated!"

Hest = Heston(**params)
time_daily, S_daily, daily_returns, daily_true_V, daily_RV = Hest.path_simulation(
    S0, V0, T_years=10, trading_days=252, intraday_intervals=39, seed=40
)
R_daily = daily_returns.copy()
# Out:
# 1.09

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 6))

# Subplot for BOTH measurements
axes[0,0].plot(time_daily, S_daily, label="Daily Stock Price", lw=0.8)
axes[0,0].set_xlabel("Time (years)")
axes[0,0].set_ylabel("Price Level")
axes[0,0].legend(loc="upper right")

# Subplot for RETURNS measurement
axes[0,1].plot(time_daily, daily_returns, label="Daily Returns", lw=0.8)
axes[0,1].set_xlabel("Time (years)")
axes[0,1].legend(loc="upper right")

# Subplot for RV measurement
axes[1,0].plot(time_daily, daily_true_V, label="True Integrated Variance", lw=0.8)
axes[1,0].set_xlabel("Time (years)")
axes[1,0].legend(loc="upper right")

# Subplot for RV measurement
axes[1,1].plot(time_daily, daily_RV, label="Daily Realized Variance", lw=0.8)
axes[1,1].set_xlabel("Time (years)")
axes[1,1].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
burnin = 252
dt = 1  # Daily

split_index = 6 * 252 

# TRAINING SET 
train_returns = daily_returns[:split_index]
train_RV = daily_RV[:split_index]

# TEST SET 
test_returns = daily_returns[split_index:]
test_RV = daily_RV[split_index:]

# %% [markdown]
# ### Both - Corr

# %%
hkf_both_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.BOTH, dt=dt, V0=0.01, P0=0.1)
hkf_both_corr.set_data(returns=train_returns, rv=train_RV)
initial_params_both_corr = np.array([0.02, 0.00015, 0.001, 0.001, 0.001, -0.4]) # kappa, theta, xi, mu, sigma, rho

fit_results_both_corr = hkf_both_corr.fit(initial_params=initial_params_both_corr, burnin=burnin)
params_opt_both_corr = fit_results_both_corr['params']
print("Optimized parameters (BOTH):", params_opt_both_corr)

train_result_both_corr = hkf_both_corr.filter(params_opt_both_corr)
last_V_train_corr = train_result_both_corr['V_filt'][-1]
last_P_train_corr = train_result_both_corr['P_filt'][-1]

hkf_both_test_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.BOTH, dt=dt, V0=last_V_train_corr, P0=last_P_train_corr)
test_result_both_corr = hkf_both_test_corr.filter(params=params_opt_both_corr, returns=test_returns, rv=test_RV)
# Out:
# QMLE Results for Heston Model:
# --------------------------------------------------
# kappa: 0.028133
# theta: 0.000138
# xi: 0.001721
# mu: 0.000675
# sigma: 0.001103
# rho: -0.598217
# Negative Log-Likelihood: -14125.246059
# Convergence: True
# --------------------------------------------------
# Optimized parameters (BOTH): [ 2.81331948e-02  1.38374200e-04  1.72147341e-03  6.74668691e-04
#   1.10327322e-03 -5.98217297e-01]

# %% [markdown]
# ### Return - Corr

# %%
# Fit the model using training data
hkf_returns_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.RETURNS, dt=dt, V0=0.02, P0=0.1)
hkf_returns_corr.set_data(returns=train_returns)
initial_params_returns_corr = np.array([0.02, 0.00015, 0.00138, 0.0002, -0.5]) # kappa, theta, xi, mu, rho

fit_results_returns_corr = hkf_returns_corr.fit(initial_params=initial_params_returns_corr, burnin=burnin)
params_opt_returns_corr = fit_results_returns_corr['params']
print("Optimized parameters (RETURNS):", params_opt_returns_corr)

train_result_returns_corr = hkf_returns_corr.filter(params_opt_returns_corr)
last_V_returns_corr = train_result_returns_corr['V_filt'][-1]
last_P_returns_corr = train_result_returns_corr['P_filt'][-1]

hkf_returns_test_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.RETURNS, dt=dt, V0=last_V_returns_corr, P0=last_P_returns_corr)
test_result_returns_corr = hkf_returns_test_corr.filter(params=params_opt_returns_corr, returns=test_returns)
# Out:
# QMLE Results for Heston Model:
# --------------------------------------------------
# kappa: 0.033709
# theta: 0.000151
# xi: 0.003729
# mu: 0.000172
# rho: -0.499961
# Negative Log-Likelihood: -3892.947794
# Convergence: True
# --------------------------------------------------
# Optimized parameters (RETURNS): [ 3.37093481e-02  1.50583821e-04  3.72894314e-03  1.72362605e-04
#  -4.99960845e-01]

# %% [markdown]
# ### PF

# %%
pf_heston_train = PFHeston(train_returns, N=10000, dt=1/252, is_log=True)

param_bounds_train = [
    (-0.1, 0.1),    # mu
    (1, 5),        # kappa
    (0.02, 0.03),    # theta
    (0.1, 0.3),    # xi
    (-0.9, 0),        # rho
    V0              # v0
]

_, estimated_param = pf_heston_train.filter(param_bounds_train, predict_obs=False)
param_bounds = list(zip(estimated_param[:,-1] - 1e-3, estimated_param[:,-1] + 1e-3))
# Out:
# resampling since: 1387.1764660857214
# resampling since: 1794.8481749566977
# resampling since: 6398.4972246062625
# resampling since: 6089.587133350503
# resampling since: 6809.288143710435
# resampling since: 6186.647572793008
# resampling since: 5398.958951308844
# resampling since: 4835.1167014454395
# resampling since: 6093.961831470367
# resampling since: 2856.5348869162426
# resampling since: 998.1576148390417
# resampling since: 5933.755328814832
# resampling since: 4528.0060077454755
# resampling since: 2624.996327052265
# resampling since: 4518.637453759446
# resampling since: 1237.9869010084312
# resampling since: 243.7544590142729
# resampling since: 6435.516066608776
# resampling since: 1756.1933167807913
# resampling since: 462.39948450927375
# resampling since: 3793.166457488334
# resampling since: 3353.9467452473546
# resampling since: 6235.997691391728
# resampling since: 5088.532284721478
# resampling since: 3222.6810813609723
# resampling since: 658.9043428957478
# resampling since: 2155.1411679237035
# resampling since: 5312.340871561223
# resampling since: 4248.267343202059
# resampling since: 6519.291839086242
# resampling since: 6269.685577850291
# resampling since: 5166.161763210094
# resampling since: 5470.8564598704315
# resampling since: 5800.450104335399
# resampling since: 5259.443072022126
# resampling since: 4187.664355786108
# resampling since: 296.99935851665896
# resampling since: 6827.858022736655
# resampling since: 3070.41390765099
# resampling since: 5268.917615148689
# resampling since: 6095.438335115152
# resampling since: 1387.0793554264867
# resampling since: 724.2669366172196
# resampling since: 6748.429889220378
# resampling since: 3294.569078649863
# resampling since: 3161.5703423202904
# resampling since: 6980.585254173213
# resampling since: 5527.104432672989
# resampling since: 6724.081423529583
# resampling since: 3201.1451252891475
# resampling since: 5230.847288311119
# resampling since: 1869.188235707816
# resampling since: 2619.7735645572843
# resampling since: 5591.018333172991
# resampling since: 3992.6233111672414
# resampling since: 4708.024710436597
# resampling since: 3961.0685926071897
# resampling since: 1338.2065895169526
# resampling since: 4167.588605818459
# resampling since: 626.05450109948
# resampling since: 6705.934438629499
# resampling since: 968.7178597077644
# resampling since: 4175.300099104443
# resampling since: 6076.321127274552
# resampling since: 5620.342673644354
# resampling since: 3275.820415543486
# resampling since: 1015.3504634412205
# resampling since: 6792.116554474964
# resampling since: 6950.350259947338
# resampling since: 1624.1491419975707
# resampling since: 3071.0514843137285
# resampling since: 1188.8439105618384
# resampling since: 2058.138351138012
# resampling since: 6583.839475025237
# resampling since: 6182.2791095404355
# resampling since: 6003.1570043328575
# resampling since: 61.82012867055097
# resampling since: 6970.212530397131
# resampling since: 1351.024338839518
# resampling since: 707.2922466305403
# resampling since: 6402.305237896616
# resampling since: 6979.5257284592135
# resampling since: 6569.80687504239
# resampling since: 5680.912605169728
# resampling since: 6209.347819353286
# resampling since: 6783.77801039146
# resampling since: 6355.106738210482
# resampling since: 5670.802385062119
# resampling since: 6580.9948781688045
# resampling since: 6729.52646198875
# resampling since: 6843.953525860328
# resampling since: 6782.0813127809315
# resampling since: 6712.606121390323
# resampling since: 3973.8270910840647
# resampling since: 5454.563388355173
# resampling since: 5271.741661822166
# resampling since: 5420.045309747788
# resampling since: 6506.812442826929
# resampling since: 5530.857945657472
# resampling since: 5361.744585952072
# resampling since: 5110.26384917415
# resampling since: 1741.779332764985
# resampling since: 912.9468890996418
# resampling since: 2573.8687456537664
# resampling since: 3695.5450071646255
# resampling since: 6560.599502175625
# resampling since: 5130.134398339145
# resampling since: 6393.398902018584
# resampling since: 2576.0936471450004
# resampling since: 5195.988169853755
# resampling since: 4096.743608351981
# resampling since: 6300.854567987446
# resampling since: 5219.54452902936
# resampling since: 2766.855076077035
# resampling since: 6985.293300013495
# resampling since: 6496.768906105689
# resampling since: 6487.723971288934
# resampling since: 5805.816217279049
# resampling since: 5783.319295397148
# resampling since: 5867.9980861325585
# resampling since: 6833.930452373705
# resampling since: 6917.471579470956
# resampling since: 6358.221515282964
# resampling since: 6993.373561789221
# resampling since: 6928.547853802273
# resampling since: 6604.116251276197
# resampling since: 2279.5002042356346
# resampling since: 5118.718422031584
# resampling since: 1935.3110254924252
# resampling since: 6090.633534705038
# resampling since: 6785.55821523393
# resampling since: 6939.418483032267
# resampling since: 6135.343000634026
# resampling since: 6233.224195956434
# resampling since: 6559.606308296026
# resampling since: 6696.491030801162
# resampling since: 4565.474754522852
# resampling since: 6148.461491247577
# resampling since: 6888.473677507215
# resampling since: 6288.7569199631225
# resampling since: 6308.832091293377
# resampling since: 6141.274344113299
# resampling since: 6566.810739937421
# resampling since: 6752.3286654795465
# resampling since: 6259.291644548776
# resampling since: 6772.408690236177
# resampling since: 6240.311261267878
# resampling since: 6661.23985592215
# resampling since: 6422.892408845845
# resampling since: 6361.430114387944
# resampling since: 6268.47366277976
# resampling since: 6177.477236898074
# resampling since: 4666.7886284509905
# resampling since: 5652.151312580064
# resampling since: 6685.312598291322
# resampling since: 6948.666382567158
# resampling since: 6644.316155000025
# resampling since: 6392.201445767781
# resampling since: 5585.847875071159
# resampling since: 6944.278873993517
# resampling since: 6996.729661674359
# resampling since: 6974.693414612043
# resampling since: 5715.2757804164685
# resampling since: 4922.240996991216
# resampling since: 6868.90425127444
# resampling since: 6185.772460639497
# resampling since: 5778.780644092154
# resampling since: 6196.808171693368
# resampling since: 6340.030305139837
# resampling since: 5874.56581028324
# resampling since: 6641.069643582967
# resampling since: 6073.519616834119
# resampling since: 5842.073194955662
# resampling since: 4350.357907080886
# resampling since: 6621.414704971414
# resampling since: 6473.782344166409
# resampling since: 6690.179232433581
# resampling since: 4868.229463795374
# resampling since: 5625.808866237036
# resampling since: 6190.20294770119
# resampling since: 6190.671527328975
# resampling since: 6142.642426179089
# resampling since: 6662.089660453485
# resampling since: 5881.441053260365
# resampling since: 6568.1025430559275
# resampling since: 6219.92904672125
# resampling since: 6950.631771959387
# resampling since: 6831.117467672853
# resampling since: 6065.659932289048
# resampling since: 6276.650887073606
# resampling since: 4563.570315981238
# resampling since: 1148.1141427395803
# resampling since: 3175.6875707528466
# resampling since: 6955.046075837217
# resampling since: 6547.992058408524
# resampling since: 6521.392699429272
# resampling since: 3816.4859475797093
# resampling since: 5578.423307710056
# resampling since: 6137.875324653453
# resampling since: 3762.3305488743995
# resampling since: 6959.713737933669
# resampling since: 6560.682080649876
# resampling since: 6365.818448606517
# resampling since: 6850.39809855947
# resampling since: 6836.260018053726
# resampling since: 3229.9293588274686
# resampling since: 4193.6620620778085
# resampling since: 4805.7144239674835
# resampling since: 6372.833558948771
# resampling since: 6937.8472973369535
# resampling since: 6407.974959138217
# resampling since: 6932.441255021652
# resampling since: 5812.33392416846
# resampling since: 6358.2460664034215
# resampling since: 5533.510362149724
# resampling since: 4244.12436508201
# resampling since: 6790.61051771065
# resampling since: 6968.59588687482
# resampling since: 6143.797151047861
# resampling since: 5179.897843485175
# resampling since: 6129.019810426446
# resampling since: 5292.849370446062
# resampling since: 5049.028513420265
# resampling since: 5088.093122053827
# resampling since: 6592.082279669423
# resampling since: 453.7572128428167
# resampling since: 5777.821387339194
# resampling since: 6206.774842136977
# resampling since: 6202.580474262007
# resampling since: 6800.409777990393
# resampling since: 954.3480589746107
# resampling since: 3256.793373356755
# resampling since: 4350.986904105113
# resampling since: 5676.655251117294
# resampling since: 6193.847318802944
# resampling since: 6707.530375649562
# resampling since: 6860.19330813081
# resampling since: 4304.319096353527
# resampling since: 6694.567794040022
# resampling since: 6949.3668635587555
# resampling since: 6591.841487558134
# resampling since: 6965.054175433256
# resampling since: 6135.294477057433
# resampling since: 5791.495606842502
# resampling since: 5754.401590245062
# resampling since: 5657.375232334308
# resampling since: 5734.825978605929
# resampling since: 6713.740478413209
# resampling since: 5556.971153483402
# resampling since: 5275.719699967963
# resampling since: 5714.762928009468
# resampling since: 4990.899513749463
# resampling since: 2590.490229699752
# resampling since: 6315.155631796102
# resampling since: 6497.750693047319
# resampling since: 6951.935435101304
# resampling since: 6857.4573320112495
# resampling since: 6559.555068655915
# resampling since: 6261.587514413746
# resampling since: 6750.553727741923
# resampling since: 4155.94116715023
# resampling since: 4979.064318923238
# resampling since: 2254.8918345788957
# resampling since: 6488.544943043682
# resampling since: 4794.555518873865
# resampling since: 3966.6057974800797
# resampling since: 6747.62810067282
# resampling since: 6056.649025170528
# resampling since: 6561.106494113339
# resampling since: 6707.73099694653
# resampling since: 6821.6777101035395
# resampling since: 5966.208302067722
# resampling since: 5209.249513895382
# resampling since: 5420.000602820561
# resampling since: 5911.628928873645
# resampling since: 6739.8467851108235
# resampling since: 6831.695106029199
# resampling since: 5092.456536455976
# resampling since: 6145.530694686131
# resampling since: 3327.6518713012733
# resampling since: 434.9771498640202
# resampling since: 6761.523402916453
# resampling since: 5952.546834337278
# resampling since: 6966.5903034396115
# resampling since: 6826.145654374108
# resampling since: 6008.889029809596
# resampling since: 5674.472450754046
# resampling since: 6544.662723616797
# resampling since: 5625.93475874965
# resampling since: 4205.477406789823
# resampling since: 4845.237788207142
# resampling since: 6541.212033205054
# resampling since: 6381.18066761731
# resampling since: 4566.911938808859
# resampling since: 5077.402505189743
# resampling since: 5423.197018704923
# resampling since: 4021.9461483672826
# resampling since: 6369.04116045936
# resampling since: 4429.296998616605
# resampling since: 1538.971179419374
# resampling since: 6813.363067282764
# resampling since: 6884.750834836921
# resampling since: 3560.1892534870644
# resampling since: 3405.4653605387102
# resampling since: 6776.1710975809065
# resampling since: 5552.4111581000925
# resampling since: 6581.881693264399
# resampling since: 3714.0029470378117

# %%
pf_heston_test = PFHeston(test_returns, N=10000, dt=1/252, is_log=True)

V_pf_train, _ = pf_heston_train.filter([*param_bounds, V0], predict_obs=False)
V_pf_test, _ = pf_heston_test.filter([*param_bounds, V_pf_train[-1]], predict_obs=False)
# Out:
# resampling since: 5893.832986696443
# resampling since: 5481.950194635339
# resampling since: 6244.6190891477145
# resampling since: 6063.033977034553
# resampling since: 1735.406471156866
# resampling since: 2839.0606092385015
# resampling since: 6743.078468671671
# resampling since: 6853.003054421185
# resampling since: 5801.272660318945
# resampling since: 4119.470326502381
# resampling since: 6611.3558166262765
# resampling since: 5411.539043176163
# resampling since: 6910.901735773726
# resampling since: 3409.8601055073627
# resampling since: 6532.940275001845
# resampling since: 6178.809745225213
# resampling since: 6194.9900219858555
# resampling since: 6241.5695004161735
# resampling since: 5407.2550226965795
# resampling since: 1149.753611002823
# resampling since: 6433.309166028303
# resampling since: 6553.825439758175
# resampling since: 6440.646504279297
# resampling since: 6674.924946282842
# resampling since: 5744.671800691241
# resampling since: 6202.378706553851
# resampling since: 6567.415711871435
# resampling since: 5343.760406268568
# resampling since: 5889.389618500169
# resampling since: 4040.589239394768
# resampling since: 4412.564153287252
# resampling since: 2380.0073459544587
# resampling since: 6576.259139391699
# resampling since: 6485.445474373694
# resampling since: 5449.52372993999
# resampling since: 6657.987915221468
# resampling since: 3488.103794024655
# resampling since: 5838.359459440798
# resampling since: 4257.270979943917
# resampling since: 6716.002593749772
# resampling since: 2234.9923641212704
# resampling since: 6916.299139470419
# resampling since: 6653.337665595745
# resampling since: 6330.1342403017015
# resampling since: 6968.795621322691
# resampling since: 6410.691037718231
# resampling since: 5679.171562766726
# resampling since: 6303.354895479436
# resampling since: 6802.884766862844
# resampling since: 5023.2575733164085
# resampling since: 6402.7314264417955
# resampling since: 6933.7662629201195
# resampling since: 6923.257570355919
# resampling since: 6663.909035053547
# resampling since: 2191.4143787963317
# resampling since: 5130.82512013809
# resampling since: 2176.93681232778
# resampling since: 6062.191355625224
# resampling since: 6812.171651206732
# resampling since: 6903.439882900204
# resampling since: 6226.543561344481
# resampling since: 6329.867118777107
# resampling since: 6357.726403719316
# resampling since: 6725.334209525779
# resampling since: 4618.685467098493
# resampling since: 6316.411287793357
# resampling since: 6903.186359840378
# resampling since: 6338.802826589147
# resampling since: 6346.13575839921
# resampling since: 6327.972070655228
# resampling since: 6572.628375865408
# resampling since: 6888.542514451123
# resampling since: 6230.391950309973
# resampling since: 6792.444533732112
# resampling since: 6413.108672851119
# resampling since: 6712.571281657266
# resampling since: 6544.916614424602
# resampling since: 6454.650296881277
# resampling since: 6173.1630795507035
# resampling since: 6148.976527335213
# resampling since: 4651.943170379525
# resampling since: 5718.764992436816
# resampling since: 6712.496691903289
# resampling since: 6994.320304536087
# resampling since: 6680.029845138683
# resampling since: 6389.63638469566
# resampling since: 5678.856009256113
# resampling since: 6915.199190434024
# resampling since: 6816.639057265759
# resampling since: 6175.7313164605985
# resampling since: 6761.86525662633
# resampling since: 5794.653484975935
# resampling since: 6153.807372685496
# resampling since: 6698.97258382379
# resampling since: 6841.365694178364
# resampling since: 5844.808898491497
# resampling since: 6648.845662106971
# resampling since: 6238.549925589382
# resampling since: 5916.624185645391
# resampling since: 4369.082698795501
# resampling since: 6699.534061929073
# resampling since: 6440.950820062267
# resampling since: 6587.74561971133
# resampling since: 4878.745373551888
# resampling since: 5685.12551688573
# resampling since: 6268.864807422247
# resampling since: 6273.14852480304
# resampling since: 6255.118959753808
# resampling since: 6652.882189724191
# resampling since: 6000.726047559261
# resampling since: 6665.646239158438
# resampling since: 6302.553256436412
# resampling since: 6954.391938486414
# resampling since: 6753.1809750890625
# resampling since: 5978.427891345395
# resampling since: 6316.421944962701
# resampling since: 4570.882116439442
# resampling since: 1075.880693650017
# resampling since: 3096.6073901163463
# resampling since: 6753.11185466745
# resampling since: 5843.178789087895
# resampling since: 6106.134590526118
# resampling since: 4026.8881632185685
# resampling since: 5656.711674737328
# resampling since: 6120.769258245406
# resampling since: 3567.5672916996186
# resampling since: 6726.981409384949
# resampling since: 6539.7998428121455
# resampling since: 6406.446338620591
# resampling since: 6466.89196824583
# resampling since: 6695.173993040335
# resampling since: 3498.970844364429
# resampling since: 4457.0000564833435
# resampling since: 4983.033974329946
# resampling since: 6602.470557933394
# resampling since: 6998.877109480214
# resampling since: 6654.1680022386545
# resampling since: 6783.286973203992
# resampling since: 5784.2482617920905
# resampling since: 6315.02596576247
# resampling since: 5432.134363477177
# resampling since: 4156.909519422848
# resampling since: 6864.694035863275
# resampling since: 6933.409248645225
# resampling since: 6217.26287499583
# resampling since: 5196.044857458056
# resampling since: 6223.4425463479
# resampling since: 5059.221251746175
# resampling since: 5065.037360799622
# resampling since: 5128.276503459879
# resampling since: 6623.201003163746
# resampling since: 418.27628107525203
# resampling since: 5692.833113315225
# resampling since: 6742.526054487394
# resampling since: 6847.237817112852
# resampling since: 6907.904700246386
# resampling since: 1466.432568700339
# resampling since: 3249.8127115742636
# resampling since: 4349.126664362129
# resampling since: 5410.88241810724
# resampling since: 5932.720622760038
# resampling since: 6971.206753491575
# resampling since: 6316.739375641807
# resampling since: 6300.6044085742005
# resampling since: 6814.012836694271
# resampling since: 6857.218867121908
# resampling since: 6498.122855636538
# resampling since: 6910.996342221512
# resampling since: 6158.43579802825
# resampling since: 5789.36132951466
# resampling since: 5731.0543826315325
# resampling since: 5660.7915015750095
# resampling since: 5682.273853574485
# resampling since: 6669.406315212375
# resampling since: 5598.4725129554245
# resampling since: 5246.263109830752
# resampling since: 5731.591975292685
# resampling since: 5084.754919299671
# resampling since: 2605.6210550422325
# resampling since: 6130.317123607635
# resampling since: 6416.848849494365
# resampling since: 6872.733499717801
# resampling since: 6944.889090311237
# resampling since: 6595.218844922206
# resampling since: 6274.903010119856
# resampling since: 6713.9456422014455
# resampling since: 4181.233578347577
# resampling since: 4954.788544919478
# resampling since: 2283.7964613835516
# resampling since: 6524.4764200708105
# resampling since: 4802.644067988896
# resampling since: 3964.5831521132823
# resampling since: 6773.095469624168
# resampling since: 6040.91785572424
# resampling since: 6496.606410512137
# resampling since: 6679.581636364546
# resampling since: 6768.7766764138505
# resampling since: 5919.144107899648
# resampling since: 5124.46546231536
# resampling since: 4893.078139112648
# resampling since: 5923.493008084645
# resampling since: 6948.152826878715
# resampling since: 5636.983037485976
# resampling since: 5509.953498789869
# resampling since: 6087.03873828181
# resampling since: 3355.628055301927
# resampling since: 811.1649341018779
# resampling since: 6909.624096424556
# resampling since: 5041.553271969867
# resampling since: 6892.40570468966
# resampling since: 5926.804435518255
# resampling since: 4764.4133633249885
# resampling since: 5532.535295045824
# resampling since: 5613.762821967717
# resampling since: 6401.164929267767
# resampling since: 6579.812193866366
# resampling since: 4087.291371100671
# resampling since: 4526.46390506268
# resampling since: 6470.001683748764
# resampling since: 6493.594342684916
# resampling since: 4622.932129527284
# resampling since: 4911.708074210124
# resampling since: 5476.054496006826
# resampling since: 4011.442211871937
# resampling since: 6405.63689225716
# resampling since: 4370.2346292751945
# resampling since: 1568.4095345043927
# resampling since: 6711.21708568522
# resampling since: 6660.270454864669
# resampling since: 3448.374518780607
# resampling since: 3215.5917578009703
# resampling since: 6701.3980712932425
# resampling since: 5578.723468753187
# resampling since: 6658.80579776281
# resampling since: 3724.9802726813714
# resampling since: 6022.96084801039
# resampling since: 6461.705332677605
# resampling since: 4257.637886568142
# resampling since: 6910.542595870335
# resampling since: 6289.402518966211
# resampling since: 6524.506682966699
# resampling since: 6777.817777202432
# resampling since: 6672.201222620594
# resampling since: 6729.487605410066
# resampling since: 6083.010646943692
# resampling since: 4737.507258016375
# resampling since: 6952.53301004956
# resampling since: 6883.159364091788
# resampling since: 6374.45104167347
# resampling since: 4744.16863556189
# resampling since: 6694.247610557707
# resampling since: 6293.649490021855
# resampling since: 6294.777026961335
# resampling since: 6967.03550387193
# resampling since: 6799.13626805568
# resampling since: 6643.9359577814885
# resampling since: 5875.030000929139
# resampling since: 6969.704657434684
# resampling since: 6971.26249754783
# resampling since: 5998.131511044236
# resampling since: 6134.927796603484
# resampling since: 6613.470317646147
# resampling since: 6456.799688096029
# resampling since: 2262.2214957804654
# resampling since: 5872.218089432102
# resampling since: 6662.452126117725
# resampling since: 6193.452649290311
# resampling since: 6149.732169029481
# resampling since: 4015.578038311623
# resampling since: 6895.673020862901
# resampling since: 4387.320844297335
# resampling since: 5310.070208256455
# resampling since: 6455.371057055691
# resampling since: 6553.234804159984
# resampling since: 5777.7133047935795
# resampling since: 6615.80147469422
# resampling since: 6918.146860231708
# resampling since: 6878.631360079584
# resampling since: 6575.756590467083
# resampling since: 6880.643919376156
# resampling since: 5933.110328280434
# resampling since: 5273.807691303998
# resampling since: 5131.885886165719
# resampling since: 6850.078222278286
# resampling since: 6116.971141850294
# resampling since: 5910.812524326185
# resampling since: 5944.307421359954
# resampling since: 6647.665410491475
# resampling since: 4396.472798994891
# resampling since: 5275.518852939373
# resampling since: 6088.459776866417
# resampling since: 4950.477242718831
# resampling since: 6663.741939406453
# resampling since: 4033.028632446847
# resampling since: 6840.777417100683
# resampling since: 4401.914911742242
# resampling since: 5744.046626851664
# resampling since: 4769.385886027298
# resampling since: 5664.183959515262
# resampling since: 6894.147314491025
# resampling since: 2701.505367465277
# resampling since: 6735.409089077825
# resampling since: 6721.125754659024
# resampling since: 6584.109502424866
# resampling since: 3053.2322889451607
# resampling since: 6383.09795527392
# resampling since: 6928.623184061323
# resampling since: 6441.116594678293
# resampling since: 4449.700237001887
# resampling since: 6348.842215307266
# resampling since: 5429.68578043952
# resampling since: 1000.6805285783378
# resampling since: 4008.2364629642457
# resampling since: 4838.641687252378
# resampling since: 6916.1576569979015
# resampling since: 6856.245751971382
# resampling since: 5787.21010791381
# resampling since: 6760.271626042534
# resampling since: 6248.463049144907
# resampling since: 4501.062018190349
# resampling since: 5032.394340866401
# resampling since: 2768.1165008475186
# resampling since: 6507.632262090295
# resampling since: 6770.806089386314
# resampling since: 4129.277870168748
# resampling since: 6684.582076328925
# resampling since: 6395.55681284493
# resampling since: 5993.7672627323755
# resampling since: 6916.3068042442355
# resampling since: 6791.244267171574
# resampling since: 6116.452569712275
# resampling since: 5389.178575623577
# resampling since: 4115.515541416866
# resampling since: 6842.2470625710475
# resampling since: 2433.669693871823
# resampling since: 6898.15831652627
# resampling since: 5836.747261807056
# resampling since: 6351.183294007388
# resampling since: 6653.250314053855
# resampling since: 6836.633226714061
# resampling since: 6759.5765549499865
# resampling since: 6291.468634233577
# resampling since: 5572.458839195691
# resampling since: 6763.872343650997
# resampling since: 6499.963249914043
# resampling since: 6872.813440721774
# resampling since: 5011.674517741323
# resampling since: 6641.515341709056
# resampling since: 5899.313275393005
# resampling since: 6346.420141038073
# resampling since: 3357.2840917017384
# resampling since: 6759.189777055212
# resampling since: 6436.215455756557
# resampling since: 6115.350061374288
# resampling since: 6711.635517227741
# resampling since: 6261.728640850328
# resampling since: 6356.002640474498
# resampling since: 6974.955320563089
# resampling since: 580.006876158214
# resampling since: 6631.4419257551635
# resampling since: 4739.0393014458905
# resampling since: 6693.468229237272
# resampling since: 6388.451202145205
# resampling since: 4237.741466022821
# resampling since: 6467.680665522435
# resampling since: 6828.675548426352
# resampling since: 6221.81371676779
# resampling since: 6402.7409973600925
# resampling since: 6563.3545117800495
# resampling since: 4784.534470274598
# resampling since: 6447.174623235485
# resampling since: 6226.68944331321
# resampling since: 5654.899124099493
# resampling since: 6426.093001274895
# resampling since: 4983.976822546964
# resampling since: 1162.114725304654
# resampling since: 3424.5209585471907
# resampling since: 4597.030339364099
# resampling since: 6974.165931385467
# resampling since: 6944.942805263193
# resampling since: 6942.687026671267
# resampling since: 6453.59347216983

# %%
V_pf_train_daily = V_pf_train / 400
V_pf_test_daily = V_pf_test / 400

# %% [markdown]
# ### Realized GARCH

# %%
# Fit the model
model = RealizedGARCH(p=1, q=1)
model.fit(train_returns, train_RV)

# Get fitted volatility (in-sample)
fitted_vol = model.get_fitted_volatility(train_returns, train_RV)

# Predict volatility (out-of-sample)
predicted_vol = model.predict(test_returns, test_RV)

# %% [markdown]
# ## Plot

# %%
v_item = 'V_pred'

titles_all = ["BOTH Measurements", "RETURNS Measurement", "Heston Particle Filter", "Realized GARCH"]
labels_all = ["Kalman BOTH", "Kalman RETURNS", "Kalman BOTH Corr", "Kalman RETURNS Corr", "PF Heston", "Realized GARCH"]
train_all = [train_result_both_corr[v_item], train_result_returns_corr[v_item], V_pf_train_daily, fitted_vol]
test_all = [test_result_both_corr[v_item], test_result_returns_corr[v_item], V_pf_test_daily, predicted_vol]

Utility.plot_all_filters(
    titles=titles_all,
    labels=labels_all,
    train_filtered_list=train_all,
    test_filtered_list=test_all,
    daily_true_V=daily_true_V,
    daily_RV=daily_RV,
    daily_returns=daily_returns,
    split_index=split_index,
    burnin=252, 
    save_path=r"./output/high_vol.png"
)

# %%
def qlike_loss(true_var, pred_var):
    y = np.asarray(true_var)
    h = np.asarray(pred_var)
    
    eps = np.finfo(float).eps
    ratio = y / (h + eps)
    return np.mean(ratio - np.log(ratio) - 1)

model_names = ['RV-QLKF', 'QLKF', 'PF', 'Realized GARCH']
true_variances   = daily_true_V[split_index:]
true_volatilities = np.sqrt(true_variances)

mae_scores   = {}
rmse_scores  = {}
qlike_scores = {}

for name, pred_var in zip(model_names, np.array(test_all).clip(1e-9, None)):
    pred_vol = np.sqrt(pred_var)
    
    mae_scores[name]   = mean_absolute_error(true_volatilities, pred_vol)
    rmse_scores[name]  = np.sqrt(mean_squared_error(true_volatilities, pred_vol))
    qlike_scores[name] = qlike_loss(true_variances, pred_var)

print("Results:")
for name in model_names:
    print(f"{name:18s} RMSE: {rmse_scores[name]:.6f}, "
          f"QLIKE: {qlike_scores[name]:.6f}")
# Out:
# Results:
# RV-QLKF            RMSE: 0.001878, QLIKE: 0.079989
# QLKF               RMSE: 0.004252, QLIKE: 547.258705
# PF                 RMSE: 0.004379, QLIKE: 0.301788
# Realized GARCH     RMSE: 0.004896, QLIKE: 0.217013

# %%
data = {}

data['RV-QLKF'] = dict(zip(
    ['kappa', 'theta', 'xi', 'mu', 'sigma', 'rho'],
    [*(params_opt_both_corr[:-1] * 252), params_opt_both_corr[-1]]
))

data['QLKF'] = dict(zip(
    ['kappa', 'theta', 'xi', 'mu', 'rho'],
    [*(params_opt_returns_corr[:-1] * 252), params_opt_returns_corr[-1]]
))
data['QLKF']['sigma'] = np.nan

pf_vals = estimated_param[:, -1]
data['PF'] = {
    'kappa': pf_vals[1],
    'theta': pf_vals[2],
    'xi':    pf_vals[3],
    'mu':    pf_vals[0],
    'rho':   pf_vals[4],
    'sigma': np.nan
}

cols = ['kappa', 'theta', 'xi', 'mu', 'sigma', 'rho']
df_params = pd.DataFrame.from_dict(data, orient='index')[cols]

df_params.T
# Out:
#         RV-QLKF      QLKF        PF
# kappa  7.089565  8.494756  1.811107
# theta  0.034870  0.037947  0.029569
# xi     0.433811  0.939694  0.287752
# mu     0.170017  0.043435 -0.039579
# sigma  0.278025       NaN       NaN
# rho   -0.598217 -0.499961 -0.037313

# %%
pd.Series(dict(zip(model.param_names[:-1], np.round(model.params[:-1], 4))))
# Out:
# omega      0.0128
# beta       0.8042
# gamma      0.1830
# xi        -0.4990
# phi        0.9405
# tau_1      0.0627
# tau_2      0.0284
# sigma_u    0.2639
# dtype: float64
