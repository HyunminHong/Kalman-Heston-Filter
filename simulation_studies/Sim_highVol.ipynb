# %%
cd ..
# Out:
# C:\Users\688228hh\Kalman-Heston-Filter

# %%
from src.Utility import Utility, MeasurementType
from src.KalmanFilterSV import HestonKalmanFilter
from src.KalmanFilterCorr import HestonKalmanFilterCorr
from src.ParticleFilter import PFHeston
from src.RealizedGARCH import RealizedGARCH
from src.Heston import *
from scipy.optimize import minimize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from arch import arch_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# Set initial conditions and simulation parameters
S0 = 100
V0 = 0.04
params = {
    'mu': 0.05,
    'rho': -0.8,
    'kappa': 11.0,
    'theta': 0.04,
    'xi': 0.9
}
std_asy = np.sqrt(params['theta'] * params['xi']**2 / (2 * params['kappa']))
feller_cond = 2 * params['kappa'] * params['theta'] / params['xi']**2
print(round(feller_cond, 2))
assert feller_cond > 1, "Feller condition is violated!"

Hest = Heston(**params)
time_daily, S_daily, daily_returns, daily_true_V, daily_RV = Hest.path_simulation(
    S0, V0, T_years=10, trading_days=252, intraday_intervals=39, seed=40
)
R_daily = daily_returns.copy()
# Out:
# 1.09

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 6))

# Subplot for BOTH measurements
axes[0,0].plot(time_daily, S_daily, label="Daily Stock Price", lw=0.8)
axes[0,0].set_xlabel("Time (years)")
axes[0,0].set_ylabel("Price Level")
axes[0,0].legend(loc="upper right")

# Subplot for RETURNS measurement
axes[0,1].plot(time_daily, daily_returns, label="Daily Returns", lw=0.8)
axes[0,1].set_xlabel("Time (years)")
axes[0,1].legend(loc="upper right")

# Subplot for RV measurement
axes[1,0].plot(time_daily, daily_true_V, label="True Integrated Variance", lw=0.8)
axes[1,0].set_xlabel("Time (years)")
axes[1,0].legend(loc="upper right")

# Subplot for RV measurement
axes[1,1].plot(time_daily, daily_RV, label="Daily Realized Variance", lw=0.8)
axes[1,1].set_xlabel("Time (years)")
axes[1,1].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
burnin = 252
dt = 1  # Daily

split_index = 6 * 252 

# TRAINING SET 
train_returns = daily_returns[:split_index]
train_RV = daily_RV[:split_index]

# TEST SET 
test_returns = daily_returns[split_index:]
test_RV = daily_RV[split_index:]

# %% [markdown]
# ### Both - Corr

# %%
hkf_both_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.BOTH, dt=dt, V0=0.01, P0=0.1)
hkf_both_corr.set_data(returns=train_returns, rv=train_RV)
initial_params_both_corr = np.array([0.02, 0.00015, 0.001, 0.001, 0.001, -0.4]) # kappa, theta, xi, mu, sigma, rho

fit_results_both_corr = hkf_both_corr.fit(initial_params=initial_params_both_corr, burnin=burnin)
params_opt_both_corr = fit_results_both_corr['params']
print("Optimized parameters (BOTH):", params_opt_both_corr)

train_result_both_corr = hkf_both_corr.filter(params_opt_both_corr)
last_V_train_corr = train_result_both_corr['V_filt'][-1]
last_P_train_corr = train_result_both_corr['P_filt'][-1]

hkf_both_test_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.BOTH, dt=dt, V0=last_V_train_corr, P0=last_P_train_corr)
test_result_both_corr = hkf_both_test_corr.filter(params=params_opt_both_corr, returns=test_returns, rv=test_RV)
# Out:
# QMLE Results for Heston Model:
# --------------------------------------------------
# kappa: 0.028133
# theta: 0.000138
# xi: 0.001721
# mu: 0.000675
# sigma: 0.001103
# rho: -0.598217
# Negative Log-Likelihood: -14125.246059
# Convergence: True
# --------------------------------------------------
# Optimized parameters (BOTH): [ 2.81331948e-02  1.38374200e-04  1.72147341e-03  6.74668691e-04
#   1.10327322e-03 -5.98217297e-01]

# %% [markdown]
# ### Return - Corr

# %%
# Fit the model using training data
hkf_returns_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.RETURNS, dt=dt, V0=0.02, P0=0.1)
hkf_returns_corr.set_data(returns=train_returns)
initial_params_returns_corr = np.array([0.02, 0.00015, 0.00138, 0.0002, -0.5]) # kappa, theta, xi, mu, rho

fit_results_returns_corr = hkf_returns_corr.fit(initial_params=initial_params_returns_corr, burnin=burnin)
params_opt_returns_corr = fit_results_returns_corr['params']
print("Optimized parameters (RETURNS):", params_opt_returns_corr)

train_result_returns_corr = hkf_returns_corr.filter(params_opt_returns_corr)
last_V_returns_corr = train_result_returns_corr['V_filt'][-1]
last_P_returns_corr = train_result_returns_corr['P_filt'][-1]

hkf_returns_test_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.RETURNS, dt=dt, V0=last_V_returns_corr, P0=last_P_returns_corr)
test_result_returns_corr = hkf_returns_test_corr.filter(params=params_opt_returns_corr, returns=test_returns)
# Out:
# QMLE Results for Heston Model:
# --------------------------------------------------
# kappa: 0.033709
# theta: 0.000151
# xi: 0.003729
# mu: 0.000172
# rho: -0.499961
# Negative Log-Likelihood: -3892.947794
# Convergence: True
# --------------------------------------------------
# Optimized parameters (RETURNS): [ 3.37093481e-02  1.50583821e-04  3.72894314e-03  1.72362605e-04
#  -4.99960845e-01]

# %% [markdown]
# ### PF

# %%
pf_heston_train = PFHeston(train_returns, N=10000, dt=1/252, is_log=True)

param_bounds_train = [
    (-0.1, 0.1),    # mu
    (1, 5),        # kappa
    (0.02, 0.03),    # theta
    (0.1, 0.3),    # xi
    (-0.9, 0),        # rho
    V0              # v0
]

_, estimated_param = pf_heston_train.filter(param_bounds_train, predict_obs=False)
param_bounds = list(zip(estimated_param[:,-1] - 1e-3, estimated_param[:,-1] + 1e-3))
# Out:
# resampling since: 1058.920254683682
# resampling since: 2709.6043636242875
# resampling since: 6065.417839672695
# resampling since: 3901.2084622978928
# resampling since: 6440.889371253871
# resampling since: 4540.091707112168
# resampling since: 5428.585726527891
# resampling since: 2535.2459590466888
# resampling since: 5134.842863978734
# resampling since: 6994.017787188359
# resampling since: 6644.263808695328
# resampling since: 5927.882845111254
# resampling since: 4617.658761635401
# resampling since: 684.1530534955281
# resampling since: 665.5642004357163
# resampling since: 4664.346142374689
# resampling since: 319.95393308473933
# resampling since: 6321.367599177621
# resampling since: 6270.614343001758
# resampling since: 6103.499957019627
# resampling since: 4521.462361978136
# resampling since: 5397.952235929671
# resampling since: 5857.150666254815
# resampling since: 6191.410076448311
# resampling since: 5420.011781544386
# resampling since: 4993.928386181169
# resampling since: 6173.996781511498
# resampling since: 2081.481888375355
# resampling since: 1485.4133989294396
# resampling since: 5764.8652760561245
# resampling since: 5877.0500058169255
# resampling since: 5901.408863544915
# resampling since: 5707.442825344031
# resampling since: 4906.298695064445
# resampling since: 2105.128834416756
# resampling since: 6265.525753699084
# resampling since: 5737.759807937648
# resampling since: 2273.1706329585113
# resampling since: 6436.78359559767
# resampling since: 4150.87868125408
# resampling since: 3413.530195028696
# resampling since: 4206.276994213828
# resampling since: 6073.189158957905
# resampling since: 6493.548489246808
# resampling since: 6834.887224708324
# resampling since: 4866.685775310686
# resampling since: 4952.751556767202
# resampling since: 159.26373325831682
# resampling since: 6856.237437512944
# resampling since: 4980.31806985005
# resampling since: 6874.651619290029
# resampling since: 6481.696712418944
# resampling since: 2797.5140330421605
# resampling since: 5059.377354846475
# resampling since: 6577.627458348323
# resampling since: 1737.7381816908971
# resampling since: 4390.627505397207
# resampling since: 2162.413341519167
# resampling since: 1394.5586811096605
# resampling since: 6462.84171829913
# resampling since: 6206.333182635126
# resampling since: 5677.397465600753
# resampling since: 835.7086869912698
# resampling since: 6783.137661276951
# resampling since: 5691.039450231362
# resampling since: 403.68732742322027
# resampling since: 4341.5028092594885
# resampling since: 6060.681995105328
# resampling since: 6622.555977801853
# resampling since: 6813.407264643931
# resampling since: 6627.109138141277
# resampling since: 6067.234810906333
# resampling since: 6577.188961169489
# resampling since: 5463.743788155084
# resampling since: 6789.932534562682
# resampling since: 6881.94300492491
# resampling since: 4245.5079356296965
# resampling since: 6058.108845196901
# resampling since: 6501.582992699822
# resampling since: 6802.975692995205
# resampling since: 6762.922471952329
# resampling since: 6857.743306312716
# resampling since: 6789.015247659701
# resampling since: 3828.419456825679
# resampling since: 4954.146557911108
# resampling since: 2885.996603300849
# resampling since: 6245.981340660022
# resampling since: 5008.284269574948
# resampling since: 6758.331510449521
# resampling since: 5366.3220331519515
# resampling since: 4254.798170450065
# resampling since: 4980.234675826277
# resampling since: 530.661943885034
# resampling since: 1494.451356892293
# resampling since: 2834.3707390767668
# resampling since: 4668.896648839307
# resampling since: 1200.7454987685128
# resampling since: 6931.264077164858
# resampling since: 2204.1382653701726
# resampling since: 4945.936145758293
# resampling since: 4320.458895693898
# resampling since: 151.2822939031124
# resampling since: 3106.8041432909117
# resampling since: 6593.312217917769
# resampling since: 4667.340832283446
# resampling since: 2517.438198734853
# resampling since: 5363.126271009756
# resampling since: 6991.621972019523
# resampling since: 6194.582255662891
# resampling since: 5882.9980979526845
# resampling since: 6663.453522427033
# resampling since: 1496.6538595803988
# resampling since: 5902.087442958978
# resampling since: 6910.064911118235
# resampling since: 6755.081864689161
# resampling since: 6854.892142944908
# resampling since: 5536.587080124666
# resampling since: 6210.123906726363
# resampling since: 5537.517980219226
# resampling since: 6641.10846842222
# resampling since: 6829.265314359996
# resampling since: 5064.073882792978
# resampling since: 6617.59013752167
# resampling since: 5668.032048463055
# resampling since: 2021.3294265840907
# resampling since: 5197.265865319772
# resampling since: 6834.3078853379675
# resampling since: 2852.8115463193158
# resampling since: 5509.177371368418
# resampling since: 1402.5613247918461
# resampling since: 6388.729108087491
# resampling since: 6817.350943441721
# resampling since: 6582.333090329014
# resampling since: 6928.942235501087
# resampling since: 6437.396214374251
# resampling since: 6947.085697121854
# resampling since: 5874.930707753525
# resampling since: 5934.106845257153
# resampling since: 4688.022354231698
# resampling since: 6123.5002054712195
# resampling since: 6080.377347577632
# resampling since: 6513.350558682059
# resampling since: 6645.38591957778
# resampling since: 6919.1786391166725
# resampling since: 6292.965357233052
# resampling since: 6187.577717781551
# resampling since: 5774.311694565579
# resampling since: 6805.896656513841
# resampling since: 6950.87942681828
# resampling since: 6110.427651079588
# resampling since: 6455.576115040665
# resampling since: 2975.1419130807894
# resampling since: 6349.936692784124
# resampling since: 5583.348304642875
# resampling since: 6911.929681623155
# resampling since: 6916.040653652166
# resampling since: 6073.188166939313
# resampling since: 6905.9042093798735
# resampling since: 6808.350751631052
# resampling since: 6201.758155879367
# resampling since: 6769.801032226026
# resampling since: 5799.916589401389
# resampling since: 6147.078934533784
# resampling since: 6636.1831311496535
# resampling since: 6810.423453496254
# resampling since: 6657.397542426695
# resampling since: 6540.740314858316
# resampling since: 5298.835134637087
# resampling since: 6472.664527147467
# resampling since: 4948.406541773629
# resampling since: 6740.766064842473
# resampling since: 5505.875178201789
# resampling since: 6245.8009558716885
# resampling since: 5534.664710140581
# resampling since: 6706.599505211556
# resampling since: 6666.629201550837
# resampling since: 6537.53024614399
# resampling since: 6834.067230272077
# resampling since: 5659.587572614094
# resampling since: 6295.400538888427
# resampling since: 6940.654230312755
# resampling since: 6681.192358570584
# resampling since: 6627.411544379643
# resampling since: 6618.248620983387
# resampling since: 5360.532789699772
# resampling since: 1167.3900078352558
# resampling since: 3646.224341089573
# resampling since: 6077.745360541059
# resampling since: 6161.116551137296
# resampling since: 4322.393003267979
# resampling since: 6161.920409293648
# resampling since: 6516.502873703522
# resampling since: 4115.7394336392945
# resampling since: 6590.452708800045
# resampling since: 4291.922554636173
# resampling since: 6127.163218717679
# resampling since: 2132.7445260155164
# resampling since: 5015.463713181486
# resampling since: 6324.917594678487
# resampling since: 6837.521940292613
# resampling since: 6462.1431300827235
# resampling since: 6391.946474533476
# resampling since: 6595.314132498269
# resampling since: 6504.082848578815
# resampling since: 5382.661997815388
# resampling since: 4911.0320001972705
# resampling since: 5920.12115742726
# resampling since: 6984.187161657474
# resampling since: 6525.562483817123
# resampling since: 6286.133160508474
# resampling since: 5055.307882617166
# resampling since: 5066.176052149767
# resampling since: 6897.986460901303
# resampling since: 6469.952524678183
# resampling since: 462.70898234872834
# resampling since: 5678.199869867069
# resampling since: 6616.834836700204
# resampling since: 6851.711500620668
# resampling since: 6912.234252057272
# resampling since: 1474.2488478286837
# resampling since: 3214.479666020841
# resampling since: 4230.9036543184575
# resampling since: 5418.557023624795
# resampling since: 6078.480920752154
# resampling since: 6863.189810264691
# resampling since: 6797.044826938759
# resampling since: 3353.9660717023976
# resampling since: 6275.176480482508
# resampling since: 6452.952676465617
# resampling since: 6930.063269707512
# resampling since: 6869.125013593658
# resampling since: 6861.744200766279
# resampling since: 6304.876300787832
# resampling since: 6152.5676143590135
# resampling since: 6155.299535299003
# resampling since: 4946.30885999314
# resampling since: 5744.255400711664
# resampling since: 6706.982424224542
# resampling since: 5326.3939356222145
# resampling since: 5830.711732668087
# resampling since: 5487.944290386644
# resampling since: 5552.582411373476
# resampling since: 2480.345552073841
# resampling since: 6161.981979128638
# resampling since: 6156.24225713084
# resampling since: 6776.001600784812
# resampling since: 5656.851149554532
# resampling since: 6681.251093282537
# resampling since: 5569.085041137099
# resampling since: 4927.277955920823
# resampling since: 6908.5242810266145
# resampling since: 6641.264722955916
# resampling since: 2309.6327811314977
# resampling since: 6732.166719066973
# resampling since: 4265.727728139162
# resampling since: 4120.687526396683
# resampling since: 6769.090549239371
# resampling since: 6114.363855718168
# resampling since: 6966.624531057664
# resampling since: 6743.283317986513
# resampling since: 6845.537706399865
# resampling since: 6936.979165828692
# resampling since: 6180.109393212049
# resampling since: 4758.096628242781
# resampling since: 5833.643881283018
# resampling since: 6448.812499946852
# resampling since: 6466.182006420766
# resampling since: 6983.869623151905
# resampling since: 6253.648732598904
# resampling since: 3535.022996885574
# resampling since: 647.9780697601578
# resampling since: 6967.675659470944
# resampling since: 6036.141036083368
# resampling since: 6863.616968411956
# resampling since: 6240.12485108663
# resampling since: 5779.256250358388
# resampling since: 5442.5371532031995
# resampling since: 6234.4397772460325
# resampling since: 5655.743336509852
# resampling since: 4340.316738204936
# resampling since: 4400.130067281457
# resampling since: 6906.557802495927
# resampling since: 6249.290730503337
# resampling since: 5976.641192769172
# resampling since: 6400.567404732373
# resampling since: 5283.514790137913
# resampling since: 5667.363895026632
# resampling since: 4770.649937724329
# resampling since: 6254.4002248968645
# resampling since: 4374.0274295086
# resampling since: 1617.3110645788688
# resampling since: 6514.3099699613695
# resampling since: 6774.540955830361
# resampling since: 2063.8929327280007
# resampling since: 2932.13068135372
# resampling since: 6590.306104919062
# resampling since: 5277.2861706407575
# resampling since: 6726.766786021157
# resampling since: 6063.581516347609
# resampling since: 3019.6479338593813

# %%
pf_heston_test = PFHeston(test_returns, N=10000, dt=1/252, is_log=True)

V_pf_train, _ = pf_heston_train.filter([*param_bounds, V0], predict_obs=False)
V_pf_test, _ = pf_heston_test.filter([*param_bounds, V_pf_train[-1]], predict_obs=False)
# Out:
# resampling since: 6186.111056619906
# resampling since: 5290.93054054844
# resampling since: 6267.550653810991
# resampling since: 6469.101026797829
# resampling since: 1880.3455496549896
# resampling since: 2995.3772538271087
# resampling since: 6900.6803489203585
# resampling since: 5362.472209895191
# resampling since: 6624.74860873463
# resampling since: 2813.633409689677
# resampling since: 5480.875622671208
# resampling since: 6969.5710311442535
# resampling since: 6768.661433537605
# resampling since: 3304.4574234906277
# resampling since: 6820.986309146325
# resampling since: 6645.00479077591
# resampling since: 6124.499017954781
# resampling since: 6554.4419990763
# resampling since: 5633.730343010772
# resampling since: 1363.361272884671
# resampling since: 6647.8078614121205
# resampling since: 6764.152265263112
# resampling since: 6632.96879700946
# resampling since: 6723.974632162137
# resampling since: 5617.3289167436205
# resampling since: 6973.574938054654
# resampling since: 6476.093978079339
# resampling since: 5612.889869126981
# resampling since: 6829.645361471273
# resampling since: 4721.458399631799
# resampling since: 4898.132967035058
# resampling since: 2743.6106175823556
# resampling since: 6700.200334744379
# resampling since: 6558.480181662962
# resampling since: 5513.627170263796
# resampling since: 2329.186717594446
# resampling since: 6684.237569810495
# resampling since: 5428.118162272818
# resampling since: 6378.502228985874
# resampling since: 4766.351682674002
# resampling since: 6535.347183698552
# resampling since: 6752.780619231173
# resampling since: 5788.14012761746
# resampling since: 5858.804757080945
# resampling since: 5985.029046908436
# resampling since: 6971.980804353034
# resampling since: 4640.436475529219
# resampling since: 6765.68886282034
# resampling since: 5928.765105197612
# resampling since: 6928.927827864063
# resampling since: 6950.229704612489
# resampling since: 1963.0017258502605
# resampling since: 5556.827217339183
# resampling since: 1769.1345389874675
# resampling since: 6277.743216568444
# resampling since: 6042.523833481081
# resampling since: 6043.399424166088
# resampling since: 6545.776625894419
# resampling since: 6880.577418536721
# resampling since: 6434.611961041281
# resampling since: 4087.4419103270816
# resampling since: 6987.820987916934
# resampling since: 5992.067931277214
# resampling since: 6947.761230906407
# resampling since: 6620.322500788508
# resampling since: 6919.405371589406
# resampling since: 6961.967654301023
# resampling since: 6969.154651796241
# resampling since: 6954.426976516011
# resampling since: 5228.050325556206
# resampling since: 6243.616917679461
# resampling since: 6085.429994826223
# resampling since: 6841.618242307022
# resampling since: 6944.410872145274
# resampling since: 6951.216952559576
# resampling since: 5021.789801247288
# resampling since: 6239.203598985242
# resampling since: 6768.362713788801
# resampling since: 6365.575536531103
# resampling since: 5644.910594407544
# resampling since: 5576.848894883435
# resampling since: 6921.94080104045
# resampling since: 6924.895410885939
# resampling since: 6814.249676131054
# resampling since: 6813.789486787609
# resampling since: 6392.9149842105135
# resampling since: 6432.289521488782
# resampling since: 5798.540743485865
# resampling since: 6186.336495491537
# resampling since: 6742.307757329762
# resampling since: 6736.670360433995
# resampling since: 6754.572988332166
# resampling since: 6520.714689565763
# resampling since: 5300.421133714233
# resampling since: 6425.5903461442595
# resampling since: 4933.436361001616
# resampling since: 6949.6960814974345
# resampling since: 6996.699939538638
# resampling since: 2507.8684702126207
# resampling since: 6242.832291491917
# resampling since: 5405.184251126408
# resampling since: 6522.156817634484
# resampling since: 6601.608744110789
# resampling since: 6582.142351900791
# resampling since: 6790.198575563094
# resampling since: 5601.599728317174
# resampling since: 6379.36549805437
# resampling since: 6935.059235275706
# resampling since: 6787.800126823407
# resampling since: 6709.124494791535
# resampling since: 6552.380138188069
# resampling since: 5380.510780570173
# resampling since: 1200.7716231169568
# resampling since: 4153.570038538521
# resampling since: 5827.88734600906
# resampling since: 6141.103832254337
# resampling since: 4169.1661148112835
# resampling since: 5976.138718510574
# resampling since: 6264.620275457284
# resampling since: 3809.4879391151667
# resampling since: 6897.969067074568
# resampling since: 4719.655187660418
# resampling since: 6358.965317720391
# resampling since: 6966.135129069752
# resampling since: 3682.177522015478
# resampling since: 4538.485754319067
# resampling since: 5772.917808365702
# resampling since: 6620.718707732577
# resampling since: 6646.569716737334
# resampling since: 6351.636963884318
# resampling since: 6376.784615662435
# resampling since: 6091.6101339861425
# resampling since: 6441.23994287399
# resampling since: 6130.058086069318
# resampling since: 6440.991144965323
# resampling since: 5802.748572589988
# resampling since: 6666.528993054884
# resampling since: 5663.063388722807
# resampling since: 5608.30247968519
# resampling since: 6660.297891652278
# resampling since: 6729.823011465701
# resampling since: 6350.7293288425435
# resampling since: 276.6300157039853
# resampling since: 6412.694146881703
# resampling since: 6821.892916039109
# resampling since: 3176.968047289164
# resampling since: 3752.218320648283
# resampling since: 4946.873681309101
# resampling since: 5781.149999296688
# resampling since: 6466.176362992074
# resampling since: 6823.222941841821
# resampling since: 4972.945830861168
# resampling since: 6612.177119450653
# resampling since: 6834.310561288412
# resampling since: 6221.1866105358895
# resampling since: 6774.541281790976
# resampling since: 6100.468624776765
# resampling since: 5543.851792109289
# resampling since: 5709.558484713394
# resampling since: 6361.750782666859
# resampling since: 6099.766341070752
# resampling since: 6795.994718764911
# resampling since: 5445.328396670702
# resampling since: 5835.685516484907
# resampling since: 5865.728095499343
# resampling since: 5904.162358416219
# resampling since: 2881.087852403065
# resampling since: 6921.38725465433
# resampling since: 6726.556998433167
# resampling since: 6761.984749963089
# resampling since: 5955.445642177765
# resampling since: 5490.509580807366
# resampling since: 6743.69463584482
# resampling since: 4347.102968315912
# resampling since: 5401.398203131514
# resampling since: 2697.411960636867
# resampling since: 6939.266430568114
# resampling since: 5231.924278638864
# resampling since: 4483.919561912799
# resampling since: 5961.277265038197
# resampling since: 6454.669199575968
# resampling since: 6862.996507074068
# resampling since: 6387.56514988104
# resampling since: 6252.999301861177
# resampling since: 5480.575196288592
# resampling since: 3361.0152305869483
# resampling since: 5385.523532080794
# resampling since: 6230.320061449619
# resampling since: 6994.626642525716
# resampling since: 5673.182873961008
# resampling since: 5994.63547110736
# resampling since: 6313.648184905381
# resampling since: 3542.502818109457
# resampling since: 582.3661372882651
# resampling since: 6824.027866373109
# resampling since: 6432.771427380688
# resampling since: 6380.367606338054
# resampling since: 5509.297178167949
# resampling since: 4943.097319850054
# resampling since: 4586.81763599978
# resampling since: 5791.733471996493
# resampling since: 4350.542979682576
# resampling since: 4929.380639011325
# resampling since: 6877.552570092242
# resampling since: 6446.327126353721
# resampling since: 6720.23453179041
# resampling since: 5359.477273638875
# resampling since: 5658.048263571672
# resampling since: 4699.551311879954
# resampling since: 6692.64182909953
# resampling since: 4499.551702676502
# resampling since: 1966.5585028483172
# resampling since: 6779.2660744615
# resampling since: 2438.092135046926
# resampling since: 3680.1862278785475
# resampling since: 6173.699796578748
# resampling since: 6976.526854092558
# resampling since: 2669.4180859965927
# resampling since: 6439.311265697584
# resampling since: 6875.513356000749
# resampling since: 4883.159477900939
# resampling since: 6880.84334739627
# resampling since: 5989.403982002686
# resampling since: 6826.825951114195
# resampling since: 5184.916127945555
# resampling since: 6381.790379810053
# resampling since: 3456.4410717154315
# resampling since: 6323.282381222868
# resampling since: 6403.671555247874
# resampling since: 6413.149026009695
# resampling since: 5146.5915259508665
# resampling since: 6255.574799603139
# resampling since: 4258.821515144714
# resampling since: 5758.323441308743
# resampling since: 6839.161177497964
# resampling since: 6096.45988266393
# resampling since: 6545.388231327097
# resampling since: 6827.260845017967
# resampling since: 6924.024479039502
# resampling since: 5523.180614243979
# resampling since: 6941.084544060981
# resampling since: 2634.106069464122
# resampling since: 6239.960901462631
# resampling since: 6979.3612568185645
# resampling since: 6369.108696669517
# resampling since: 6654.850551172437
# resampling since: 4400.674921878228
# resampling since: 6780.526552114513
# resampling since: 4009.5299356743935
# resampling since: 6029.706698976273
# resampling since: 6574.964714458278
# resampling since: 6382.452391021257
# resampling since: 5740.787880106055
# resampling since: 6752.3653469062665
# resampling since: 6608.940858600155
# resampling since: 4330.483215331588
# resampling since: 5778.074396022409
# resampling since: 5417.378951973466
# resampling since: 6049.578838687263
# resampling since: 5770.954823052199
# resampling since: 5373.455594027775
# resampling since: 6247.636196099505
# resampling since: 6501.863597651674
# resampling since: 6612.767232422691
# resampling since: 5674.130912887291
# resampling since: 6161.731759840068
# resampling since: 5317.620918383247
# resampling since: 6038.187367392159
# resampling since: 6499.834014216881
# resampling since: 6399.345621162318
# resampling since: 3489.843485787382
# resampling since: 6154.058443288401
# resampling since: 5205.058122116153
# resampling since: 6375.567276605091
# resampling since: 5694.224167794976
# resampling since: 2431.1458523874994
# resampling since: 6031.320627716765
# resampling since: 6864.357564555234
# resampling since: 6004.495636888932
# resampling since: 5976.890758586291
# resampling since: 6556.336442921706
# resampling since: 3759.4361671372144
# resampling since: 6887.459573823099
# resampling since: 5855.060231849535
# resampling since: 1559.9990149292667
# resampling since: 5373.947879430126
# resampling since: 5046.099250366734
# resampling since: 6843.4327181314175
# resampling since: 6904.491831224431
# resampling since: 6697.2575959352525
# resampling since: 6034.8980010930545
# resampling since: 5556.879694080562
# resampling since: 5490.8877027577
# resampling since: 4162.114773961192
# resampling since: 2964.2453114321984
# resampling since: 5696.004972695192
# resampling since: 6877.590759827678
# resampling since: 3247.559838878061
# resampling since: 5975.894330193559
# resampling since: 6064.882299319326
# resampling since: 6951.768217060767
# resampling since: 6517.42034578725
# resampling since: 6722.99711186059
# resampling since: 4935.460400295864
# resampling since: 1919.7899232860186
# resampling since: 6690.3417714341085
# resampling since: 6673.761142890156
# resampling since: 4832.6703644700765
# resampling since: 4801.851202660003
# resampling since: 6149.149905825602
# resampling since: 6872.411988540859
# resampling since: 6004.988709262253
# resampling since: 6673.448499908314
# resampling since: 5985.375461741775
# resampling since: 3058.6159891918364
# resampling since: 6838.166407280741
# resampling since: 6430.851224864081
# resampling since: 6809.2243883777
# resampling since: 3519.299192558514
# resampling since: 6714.8816605183665
# resampling since: 6243.136650275512
# resampling since: 6222.259381976249
# resampling since: 6482.968426129235
# resampling since: 6956.206619480876
# resampling since: 1374.141648129821
# resampling since: 6801.618078861781
# resampling since: 5053.679904348187
# resampling since: 6829.476555906225
# resampling since: 3319.0711019562546
# resampling since: 6957.563934387002
# resampling since: 6188.619934285785
# resampling since: 5892.311420085943
# resampling since: 6723.874998935769
# resampling since: 6954.108955566586
# resampling since: 6492.791822456765
# resampling since: 6890.118970916956
# resampling since: 5524.174169744937
# resampling since: 1449.3551163775
# resampling since: 2825.901173399226
# resampling since: 5715.441631144804
# resampling since: 6834.971705327914
# resampling since: 6406.527728581065

# %%
V_pf_train_daily = V_pf_train / 400
V_pf_test_daily = V_pf_test / 400

# %% [markdown]
# ### Realized GARCH

# %%
# Fit the model
model = RealizedGARCH(p=1, q=1)
model.fit(train_returns, train_RV)

# Get fitted volatility (in-sample)
fitted_vol = model.get_fitted_volatility(train_returns, train_RV)

# Predict volatility (out-of-sample)
predicted_vol = model.predict(test_returns, test_RV)

# %% [markdown]
# ## Plot

# %%
v_item = 'V_pred'

titles_all = ["BOTH Measurements", "RETURNS Measurement", "Heston Particle Filter", "Realized GARCH"]
labels_all = ["Kalman BOTH", "Kalman RETURNS", "Kalman BOTH Corr", "Kalman RETURNS Corr", "PF Heston", "Realized GARCH"]
train_all = [train_result_both_corr[v_item], train_result_returns_corr[v_item], V_pf_train_daily, fitted_vol]
test_all = [test_result_both_corr[v_item], test_result_returns_corr[v_item], V_pf_test_daily, predicted_vol]

Utility.plot_all_filters(
    titles=titles_all,
    labels=labels_all,
    train_filtered_list=train_all,
    test_filtered_list=test_all,
    daily_true_V=daily_true_V,
    daily_RV=daily_RV,
    daily_returns=daily_returns,
    split_index=split_index,
    burnin=252, 
    save_path=r"./output/high_vol.png"
)

# %%
def qlike_loss(true_var, pred_var):
    y = np.asarray(true_var)
    h = np.asarray(pred_var)
    
    eps = np.finfo(float).eps
    ratio = y / (h + eps)
    return np.mean(ratio - np.log(ratio) - 1)

model_names = ['RV-QLKF', 'QLKF', 'PF', 'Realized GARCH']
true_variances   = daily_true_V[split_index:]
true_volatilities = np.sqrt(true_variances)

mae_scores   = {}
rmse_scores  = {}
qlike_scores = {}

for name, pred_var in zip(model_names, np.array(test_all).clip(1e-9, None)):
    pred_vol = np.sqrt(pred_var)
    
    mae_scores[name]   = mean_absolute_error(true_volatilities, pred_vol)
    rmse_scores[name]  = np.sqrt(mean_squared_error(true_volatilities, pred_vol))
    qlike_scores[name] = qlike_loss(true_variances, pred_var)

print("Results:")
for name in model_names:
    print(f"{name:18s} RMSE: {rmse_scores[name]:.6f}, "
          f"QLIKE: {qlike_scores[name]:.6f}")
# Out:
# Results:
# RV-QLKF            RMSE: 0.001878, QLIKE: 0.079989
# QLKF               RMSE: 0.004252, QLIKE: 547.258705
# PF                 RMSE: 0.004401, QLIKE: 0.298031
# Realized GARCH     RMSE: 0.004896, QLIKE: 0.217013

# %%
data = {}

data['RV-QLKF'] = dict(zip(
    ['kappa', 'theta', 'xi', 'mu', 'sigma', 'rho'],
    [*(params_opt_both_corr[:-1] * 252), params_opt_both_corr[-1]]
))

data['QLKF'] = dict(zip(
    ['kappa', 'theta', 'xi', 'mu', 'rho'],
    [*(params_opt_returns_corr[:-1] * 252), params_opt_returns_corr[-1]]
))
data['QLKF']['sigma'] = np.nan

pf_vals = estimated_param[:, -1]
data['PF'] = {
    'kappa': pf_vals[1],
    'theta': pf_vals[2],
    'xi':    pf_vals[3],
    'mu':    pf_vals[0],
    'rho':   pf_vals[4],
    'sigma': np.nan
}

cols = ['kappa', 'theta', 'xi', 'mu', 'sigma', 'rho']
df_params = pd.DataFrame.from_dict(data, orient='index')[cols]

df_params.T
# Out:
#         RV-QLKF      QLKF        PF
# kappa  7.089565  8.494756  1.811107
# theta  0.034870  0.037947  0.029569
# xi     0.433811  0.939694  0.287752
# mu     0.170017  0.043435 -0.039579
# sigma  0.278025       NaN       NaN
# rho   -0.598217 -0.499961 -0.037313

# %%
pd.Series(dict(zip(model.param_names[:-1], np.round(model.params[:-1], 3))))
# Out:
# omega      0.013
# beta       0.804
# gamma      0.183
# xi        -0.499
# phi        0.940
# tau_1      0.063
# tau_2      0.028
# sigma_u    0.264
# dtype: float64
