# %%
cd ..
# Out:
# /Users/hyunminhong/Kalman-Heston-Filter

# %%
from src.Utility import Utility, MeasurementType
from src.KalmanFilterSV import HestonKalmanFilter
from src.KalmanFilterCorr import HestonKalmanFilterCorr
from src.ParticleFilter import PFHeston
from src.RealizedGARCH import RealizedGARCH
from src.Heston import *
from scipy.optimize import minimize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from arch import arch_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
# Out:
# /Users/hyunminhong/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Set initial conditions and simulation parameters
S0 = 100
V0 = 0.04
params = {
    'mu': 0.05,
    'rho': 0,
    'kappa': 5.0,
    'theta': 0.04,
    'xi': 0.35
}
std_asy = np.sqrt(params['theta'] * params['xi']**2 / (2 * params['kappa']))
feller_cond = 2 * params['kappa'] * params['theta'] / params['xi']**2
print(round(feller_cond, 2))
assert feller_cond > 1, "Feller condition is violated!"

Hest = Heston(**params)
time_daily, S_daily, daily_returns, daily_true_V, daily_RV = Hest.path_simulation(
    S0, V0, T_years=10, trading_days=252, intraday_intervals=39, seed=40
)
R_daily = daily_returns.copy()
# Out:
# 3.27

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 6))

# Subplot for BOTH measurements
axes[0,0].plot(time_daily, S_daily, label="Daily Stock Price", lw=0.8)
axes[0,0].set_xlabel("Time (years)")
axes[0,0].set_ylabel("Price Level")
axes[0,0].legend(loc="upper right")

# Subplot for RETURNS measurement
axes[0,1].plot(time_daily, daily_returns, label="Daily Returns", lw=0.8)
axes[0,1].set_xlabel("Time (years)")
axes[0,1].legend(loc="upper right")

# Subplot for RV measurement
axes[1,0].plot(time_daily, daily_true_V, label="True Integrated Variance", lw=0.8)
axes[1,0].set_xlabel("Time (years)")
axes[1,0].legend(loc="upper right")

# Subplot for RV measurement
axes[1,1].plot(time_daily, daily_RV, label="Daily Realized Variance", lw=0.8)
axes[1,1].set_xlabel("Time (years)")
axes[1,1].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
burnin = 252
dt = 1  # Daily

split_index = 6 * 252 

# TRAINING SET 
train_returns = daily_returns[:split_index]
train_RV = daily_RV[:split_index]

# TEST SET 
test_returns = daily_returns[split_index:]
test_RV = daily_RV[split_index:]

# %% [markdown]
# ### Both - Corr

# %%
hkf_both_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.BOTH, dt=dt, V0=0.01, P0=0.1)
hkf_both_corr.set_data(returns=train_returns, rv=train_RV)
initial_params_both_corr = np.array([0.02, 0.00015, 0.001, 0.001, 0.001, 0]) # kappa, theta, xi, mu, sigma, rho

fit_results_both_corr = hkf_both_corr.fit(initial_params=initial_params_both_corr, burnin=burnin)
params_opt_both_corr = fit_results_both_corr['params']
print("Optimized parameters (BOTH):", params_opt_both_corr)

train_result_both_corr = hkf_both_corr.filter(params_opt_both_corr)
last_V_train_corr = train_result_both_corr['V_filt'][-1]
last_P_train_corr = train_result_both_corr['P_filt'][-1]

hkf_both_test_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.BOTH, dt=dt, V0=last_V_train_corr, P0=last_P_train_corr)
test_result_both_corr = hkf_both_test_corr.filter(params=params_opt_both_corr, returns=test_returns, rv=test_RV)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.40480D+04    |proj g|=  8.73164D+03
#
# At iterate    1    f= -1.40483D+04    |proj g|=  9.90000D-01
#
# At iterate    2    f= -1.40498D+04    |proj g|=  3.49523D+04
#
# At iterate    3    f= -1.40500D+04    |proj g|=  1.45955D+04
#
# At iterate    4    f= -1.40506D+04    |proj g|=  9.90000D-01
#
# At iterate    5    f= -1.40527D+04    |proj g|=  9.89999D-01
#
# At iterate    6    f= -1.40558D+04    |proj g|=  9.89998D-01
#
# At iterate    7    f= -1.40591D+04    |proj g|=  9.89997D-01
#
# At iterate    8    f= -1.40620D+04    |proj g|=  1.38975D+04
#
# At iterate    9    f= -1.40620D+04    |proj g|=  1.18823D+03
#
# At iterate   10    f= -1.40620D+04    |proj g|=  2.72216D+03
#
# At iterate   11    f= -1.40621D+04    |proj g|=  1.07693D+04
#
# At iterate   12    f= -1.40622D+04    |proj g|=  1.26229D+04
#
# At iterate   13    f= -1.40622D+04    |proj g|=  4.03250D+03
#
# At iterate   14    f= -1.40622D+04    |proj g|=  4.46646D+03
#
# At iterate   15    f= -1.40622D+04    |proj g|=  9.89994D-01
#
# At iterate   16    f= -1.40622D+04    |proj g|=  9.89994D-01
#
# At iterate   17    f= -1.40623D+04    |proj g|=  4.95792D+02
#
# At iterate   18    f= -1.40630D+04    |proj g|=  4.70349D+03
#
# At iterate   19    f= -1.40637D+04    |proj g|=  7.92879D+03
#
# At iterate   20    f= -1.40641D+04    |proj g|=  1.00469D+04
#
# At iterate   21    f= -1.40642D+04    |proj g|=  7.74381D+03
#
# At iterate   22    f= -1.40642D+04    |proj g|=  3.81148D+03
#
# At iterate   23    f= -1.40643D+04    |proj g|=  2.74556D+03
#
# At iterate   24    f= -1.40643D+04    |proj g|=  1.87051D+03
#
# At iterate   25    f= -1.40643D+04    |proj g|=  6.21822D+01
#
# QMLE Results for Heston Model:
# At iterate   26    f= -1.40643D+04    |proj g|=  2.08529D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     26     36     32     0     1   2.085D+00  -1.406D+04
#   F =  -14064.295311590871
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# --------------------------------------------------
# kappa: 0.009827
# theta: 0.000145
# xi: 0.000979
# mu: 0.000376
# sigma: 0.000001
# rho: -0.000256
# Negative Log-Likelihood: -14064.295312
# Convergence: True
# --------------------------------------------------
# Optimized parameters (BOTH): [ 9.82660883e-03  1.44905012e-04  9.79234292e-04  3.76334797e-04
#   1.00000000e-06 -2.55949348e-04]

# %% [markdown]
# ### Return - Corr

# %%
# Fit the model using training data
hkf_returns_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.RETURNS, dt=dt, V0=0.02, P0=0.1)
hkf_returns_corr.set_data(returns=train_returns)
initial_params_returns_corr = np.array([0.02, 0.00015, 0.00138, 0.0002, 0]) # kappa, theta, xi, mu, rho

fit_results_returns_corr = hkf_returns_corr.fit(initial_params=initial_params_returns_corr, burnin=burnin)
params_opt_returns_corr = fit_results_returns_corr['params']
print("Optimized parameters (RETURNS):", params_opt_returns_corr)

train_result_returns_corr = hkf_returns_corr.filter(params_opt_returns_corr)
last_V_returns_corr = train_result_returns_corr['V_filt'][-1]
last_P_returns_corr = train_result_returns_corr['P_filt'][-1]

hkf_returns_test_corr = HestonKalmanFilterCorr(measurement_type=MeasurementType.RETURNS, dt=dt, V0=last_V_returns_corr, P0=last_P_returns_corr)
test_result_returns_corr = hkf_returns_test_corr.filter(params=params_opt_returns_corr, returns=test_returns)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.72685D+03    |proj g|=  1.84567D+05
#
# At iterate    1    f= -3.72700D+03    |proj g|=  2.01171D+02
#
# At iterate    2    f= -3.72745D+03    |proj g|=  1.58155D+02
#
# At iterate    3    f= -3.72745D+03    |proj g|=  1.26853D+03
#
# At iterate    4    f= -3.72749D+03    |proj g|=  1.27873D+02
#
# At iterate    5    f= -3.72749D+03    |proj g|=  1.27613D+02
#
# At iterate    6    f= -3.72749D+03    |proj g|=  1.26173D+02
#
# At iterate    7    f= -3.72749D+03    |proj g|=  3.19921D+03
#
# At iterate    8    f= -3.72749D+03    |proj g|=  8.84685D+03
#
# At iterate    9    f= -3.72750D+03    |proj g|=  1.45561D+04
#
# At iterate   10    f= -3.72750D+03    |proj g|=  1.49734D+04
#
# At iterate   11    f= -3.72754D+03    |proj g|=  4.64385D+04
#
# At iterate   12    f= -3.72756D+03    |proj g|=  3.30085D+04
#
# At iterate   13    f= -3.72758D+03    |proj g|=  7.05047D+03
#
# At iterate   14    f= -3.72758D+03    |proj g|=  7.16067D+02
#
# At iterate   15    f= -3.72758D+03    |proj g|=  5.19332D+01
#
# At iterate   16    f= -3.72758D+03    |proj g|=  5.19395D+01
#
# At iterate   17    f= -3.72758D+03    |proj g|=  5.17466D+01
#
# At iterate   18    f= -3.72758D+03    |proj g|=  5.08193D+01
#
# At iterate   19    f= -3.72761D+03    |proj g|=  3.61366D+01
#   ys=-2.128E-01  -gs= 1.157E-02 BFGS update SKIPPED
#
# At iterate   20    f= -3.72762D+03    |proj g|=  5.49698D+01
#
# At iterate   21    f= -3.72762D+03    |proj g|=  6.90562D+01
#
# At iterate   22    f= -3.72764D+03    |proj g|=  1.19089D+04
#
# At iterate   23    f= -3.72766D+03    |proj g|=  2.47026D+04
#
# At iterate   24    f= -3.72773D+03    |proj g|=  4.72940D+04
#
# At iterate   25    f= -3.72775D+03    |proj g|=  5.27395D+04
#
# At iterate   26    f= -3.72782D+03    |proj g|=  8.64429D+03
#
# At iterate   27    f= -3.72783D+03    |proj g|=  2.34859D+00
#
# At iterate   28    f= -3.72783D+03    |proj g|=  7.34485D+00
#
# At iterate   29    f= -3.72783D+03    |proj g|=  1.23923D+03
#
# At iterate   30    f= -3.72783D+03    |proj g|=  5.09305D+02
#
# At iterate   31    f= -3.72783D+03    |proj g|=  1.08979D+01
#
# At iterate   32    f= -3.72783D+03    |proj g|=  5.63041D+00
#
# At iterate   33    f= -3.72783D+03    |proj g|=  2.38697D-01
#
# At iterate   34    f= -3.72783D+03    |proj g|=  2.99997D-01
#
# At iterate   35    f= -3.72783D+03    |proj g|=  4.55157D-01
#
# At iterate   36    f= -3.72783D+03    |proj g|=  7.52198D-01
#
# At iterate   37    f= -3.72783D+03    |proj g|=  1.09681D+00
#
# At iterate   38    f= -3.72784D+03    |proj g|=  2.29829D-01
#
# At iterate   39    f= -3.72785D+03    |proj g|=  2.00264D-01
#
# At iterate   40    f= -3.72786D+03    |proj g|=  6.43963D+03
#
# At iterate   41    f= -3.72786D+03    |proj g|=  5.70196D+03
#
# At iterate   42    f= -3.72786D+03    |proj g|=  1.10745D+00
#
# At iterate   43    f= -3.72787D+03    |proj g|=  1.64164D+00
#
# QMLE Results for Heston Model:
# At iterate   44    f= -3.72787D+03    |proj g|=  1.09920D+02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     44    111     47     1     0   1.099D+02  -3.728D+03
#   F =  -3727.8651354647632
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# --------------------------------------------------
# kappa: 0.024773
# theta: 0.000157
# xi: 0.000001
# mu: 0.000264
# rho: 0.001173
# Negative Log-Likelihood: -3727.865135
# Convergence: True
# --------------------------------------------------
# Optimized parameters (RETURNS): [2.47732463e-02 1.57082559e-04 1.00234729e-06 2.64285383e-04
#  1.17283538e-03]

# %% [markdown]
# ### PF

# %%
pf_heston_train = PFHeston(train_returns, N=10000, dt=1/252, is_log=True)

param_bounds_train = [
    (-0.1, 0.1),    # mu
    (1, 5),        # kappa
    (0.02, 0.03),    # theta
    (0.1, 0.3),    # xi
    (-0.9, 0),        # rho
    V0              # v0
]

_, estimated_param = pf_heston_train.filter(param_bounds_train, predict_obs=False)
param_bounds = list(zip(estimated_param[:,-1] - 1e-3, estimated_param[:,-1] + 1e-3))
# Out:
# resampling since: 2552.1828637390513
# resampling since: 5520.948291014139
# resampling since: 3671.5137088177457
# resampling since: 5051.273221252661
# resampling since: 1353.4520848035834
# resampling since: 3124.3343831437383
# resampling since: 4333.3596378719885
# resampling since: 261.4784354363378
# resampling since: 3340.8203061523136
# resampling since: 733.3836232657485
# resampling since: 6.460261990076625
# resampling since: 4316.703414776147
# resampling since: 470.50146895342937
# resampling since: 1637.3409485755108
# resampling since: 2959.2507889500343
# resampling since: 4502.243708560277
# resampling since: 3215.493395525435
# resampling since: 2503.7073952281307
# resampling since: 131.40522497982175
# resampling since: 5407.455556180079
# resampling since: 114.02972665523536
# resampling since: 3143.2745105648005
# resampling since: 3529.111277381406
# resampling since: 2948.9492255040423
# resampling since: 1629.7103121564915
# resampling since: 2007.013912114553
# resampling since: 167.8099799694301
# resampling since: 3826.034781369505
# resampling since: 2387.890633704987
# resampling since: 25.76236941292526
# resampling since: 113.8889198776721
# resampling since: 223.80578158521675
# resampling since: 80.12929212850706
# resampling since: 5938.076617554976
# resampling since: 5087.9963110635335
# resampling since: 3599.188830551746
# resampling since: 4532.185404369343
# resampling since: 3836.5705772409196
# resampling since: 93.00546307571983
# resampling since: 3389.987173922991
# resampling since: 5575.573603759091
# resampling since: 4388.299750909294
# resampling since: 1469.4946361183627
# resampling since: 5742.882690271692
# resampling since: 6626.489564351821
# resampling since: 392.86878775847845
# resampling since: 5313.9962546474635
# resampling since: 5161.644343117932
# resampling since: 4995.345223316033
# resampling since: 6438.178095609918
# resampling since: 1228.0290073350816
# resampling since: 3091.263689812848
# resampling since: 3019.3319041388972
# resampling since: 1478.8084285285931
# resampling since: 6347.4371064042725
# resampling since: 579.5442189536695
# resampling since: 4125.136659040288
# resampling since: 1577.4682259829783
# resampling since: 837.0108910810495
# resampling since: 620.7240784505082
# resampling since: 1186.5889057681666
# resampling since: 1772.7201359329836
# resampling since: 1860.7643843138299
# resampling since: 3605.5389849669964
# resampling since: 2457.186790503626
# resampling since: 6595.96479812857
# resampling since: 917.0235135456926
# resampling since: 809.0396171341129
# resampling since: 4002.7149596553268
# resampling since: 913.9935302058128
# resampling since: 6367.221610004643
# resampling since: 5823.447210525262
# resampling since: 5442.5411585452375
# resampling since: 4840.593915325884
# resampling since: 1556.0505734289686
# resampling since: 4597.505248501501
# resampling since: 5286.783373515927
# resampling since: 3523.194527920683
# resampling since: 4887.014404187843
# resampling since: 6320.553031007258
# resampling since: 6021.315630374225
# resampling since: 4875.458665151813
# resampling since: 5935.051033144777
# resampling since: 6440.288918990296
# resampling since: 6276.299211917263
# resampling since: 3803.7347851807867
# resampling since: 2294.3665775729373
# resampling since: 2531.6858728783563
# resampling since: 1359.9210347564388
# resampling since: 3372.7852559150424
# resampling since: 4644.254765061526
# resampling since: 771.2299765694434
# resampling since: 506.43312937565236
# resampling since: 5019.562143601608
# resampling since: 5762.3662461510285
# resampling since: 6293.895186066849
# resampling since: 4738.539921836817
# resampling since: 5423.288082719789
# resampling since: 1590.121352173475
# resampling since: 5823.338510020429
# resampling since: 4088.6267787599586
# resampling since: 2854.5181384642156
# resampling since: 5833.036396723975
# resampling since: 5200.17291371565
# resampling since: 887.5405854606714
# resampling since: 6863.536532335203
# resampling since: 4992.975287137907
# resampling since: 6560.710776889392
# resampling since: 6722.698391870281
# resampling since: 6222.274790342099
# resampling since: 2351.630608315379
# resampling since: 5507.338516242045
# resampling since: 4959.141413538038
# resampling since: 3055.5213442988875
# resampling since: 4579.258027261079
# resampling since: 3459.9474602292776
# resampling since: 1611.989731673453
# resampling since: 2812.7493303176316
# resampling since: 1018.631989983771
# resampling since: 4958.198976435617
# resampling since: 6123.257789500992
# resampling since: 5952.531844255402
# resampling since: 5507.510279607441
# resampling since: 552.2270642006337
# resampling since: 1553.199448233484
# resampling since: 5755.061869431187
# resampling since: 3098.2124083792664
# resampling since: 6781.911256221539
# resampling since: 3716.1570656268104
# resampling since: 2659.1347067328857
# resampling since: 5256.568652753704
# resampling since: 2370.515374920178
# resampling since: 4184.203813345256
# resampling since: 5742.501392604806
# resampling since: 6072.584563127571
# resampling since: 4015.7718881921237
# resampling since: 3371.5830683465283
# resampling since: 4586.460616020958
# resampling since: 5578.769521068836
# resampling since: 907.5998796063192
# resampling since: 2097.699877879712
# resampling since: 2292.343082084167
# resampling since: 1776.0894541851703
# resampling since: 6995.140579573231
# resampling since: 3147.7947214913443
# resampling since: 2475.9132953745407
# resampling since: 4648.770254852606
# resampling since: 2773.786704524153
# resampling since: 6593.761405506191
# resampling since: 2581.9083808881446
# resampling since: 589.5202543332874
# resampling since: 6295.985347793173
# resampling since: 775.9680192125255
# resampling since: 259.5716484574107
# resampling since: 1829.6778122603191
# resampling since: 3937.448728329349
# resampling since: 994.791745211041
# resampling since: 3294.758454250579
# resampling since: 4219.116675054555
# resampling since: 6631.952910206237
# resampling since: 4122.502466850479
# resampling since: 4513.832960162143
# resampling since: 3723.9032664445876
# resampling since: 6026.895877563306
# resampling since: 5730.82200286878
# resampling since: 914.6166479268212
# resampling since: 5594.3652041450105
# resampling since: 4033.603795449049
# resampling since: 5294.615517446215
# resampling since: 5195.56582013287
# resampling since: 6701.680236691904
# resampling since: 6760.136099123149
# resampling since: 4139.203772406312
# resampling since: 6969.7943064747815
# resampling since: 6479.708147230176
# resampling since: 6699.9038936750985
# resampling since: 6415.815594012214
# resampling since: 6799.960999782262
# resampling since: 5255.0522954716025
# resampling since: 6318.872889141074
# resampling since: 5916.698629154658
# resampling since: 6051.02214126874
# resampling since: 6022.941111240169
# resampling since: 6850.358395778449
# resampling since: 6455.017746291571
# resampling since: 5904.916418911363
# resampling since: 6792.817305548567
# resampling since: 3478.1212528448978
# resampling since: 2785.741414316145
# resampling since: 3574.4546814197543
# resampling since: 5587.567184193827
# resampling since: 5579.453777422437
# resampling since: 6136.849388307785
# resampling since: 6271.517136031625
# resampling since: 6409.771033754999
# resampling since: 6846.36052828738
# resampling since: 6002.213960076972
# resampling since: 6214.889774684038
# resampling since: 3613.8378811291777
# resampling since: 6535.95007033177
# resampling since: 5634.670703753718
# resampling since: 6033.257487219224
# resampling since: 6723.758234467225
# resampling since: 6822.85829141391
# resampling since: 5967.416566739311
# resampling since: 6412.296009791696
# resampling since: 5905.623117722175
# resampling since: 3143.1696841253915
# resampling since: 3081.2885513445653
# resampling since: 6761.325680725654
# resampling since: 6373.944229093125
# resampling since: 6256.422781588304
# resampling since: 4995.082794049442
# resampling since: 6710.096514790437
# resampling since: 5992.729843908236
# resampling since: 4154.463024939531
# resampling since: 4407.392896004124
# resampling since: 2631.5511732599352
# resampling since: 6470.96960086628
# resampling since: 1977.2046854940352
# resampling since: 5375.321500519158
# resampling since: 6937.4312020500565
# resampling since: 6846.873255165676
# resampling since: 6854.745891187939
# resampling since: 5852.100110382481
# resampling since: 4601.1373088046
# resampling since: 5488.471276793619
# resampling since: 5684.729447972018
# resampling since: 4654.097414905286
# resampling since: 4251.817059611318
# resampling since: 6178.615826111479
# resampling since: 4952.814257884727
# resampling since: 6371.126881493767
# resampling since: 5050.072611836814
# resampling since: 6681.512682304544
# resampling since: 5673.5834271017575
# resampling since: 5939.345555423731
# resampling since: 6182.327398687564
# resampling since: 6811.506487160134
# resampling since: 6573.800666346036
# resampling since: 5951.575766934601
# resampling since: 5499.10199671926
# resampling since: 6405.9635075627375
# resampling since: 5270.029569231701
# resampling since: 6179.486023901702
# resampling since: 2729.5889348901696
# resampling since: 5487.594443866108
# resampling since: 6528.267143449479
# resampling since: 6511.908447499496
# resampling since: 6870.60302725036
# resampling since: 6147.4930510216345
# resampling since: 6244.313325449667
# resampling since: 5333.19838549013
# resampling since: 4018.5186108635926
# resampling since: 6768.390365688313
# resampling since: 6966.75495864619
# resampling since: 2741.2481975353253
# resampling since: 6450.722555004349
# resampling since: 6838.595394737213
# resampling since: 2933.758899120654
# resampling since: 6184.1011640673105
# resampling since: 6415.793321035752
# resampling since: 6777.91453792099
# resampling since: 5752.662255843522
# resampling since: 6669.734557231819
# resampling since: 4908.573480054476
# resampling since: 4321.469603340743
# resampling since: 6768.890305005086
# resampling since: 6935.394037559494
# resampling since: 6261.829115681089
# resampling since: 6915.992370446342
# resampling since: 6843.378202674879
# resampling since: 4191.178787055753
# resampling since: 5964.172574170362
# resampling since: 3608.40009397156
# resampling since: 6248.034215616838
# resampling since: 6134.066057321196
# resampling since: 3847.752190324222
# resampling since: 6359.534980008229
# resampling since: 5940.666327274853
# resampling since: 4184.27491165729
# resampling since: 6967.843513222721
# resampling since: 4731.428057640067
# resampling since: 4823.5040931929825
# resampling since: 6281.963867561396
# resampling since: 5383.745586775013
# resampling since: 3960.496010807311
# resampling since: 3754.737351457327
# resampling since: 2981.006476411253
# resampling since: 4647.846905049819
# resampling since: 3019.8066471710877
# resampling since: 5260.387698121622
# resampling since: 6519.316163800722
# resampling since: 6795.8360738590245
# resampling since: 6757.806534924046
# resampling since: 6671.218988251738
# resampling since: 5927.731845525054
# resampling since: 6752.822717533249
# resampling since: 6748.198268070367
# resampling since: 5792.828517059022
# resampling since: 6456.034482497218
# resampling since: 6663.705756939389
# resampling since: 6946.247743218681
# resampling since: 5582.599237565461
# resampling since: 6837.854100386896
# resampling since: 6629.194663523257
# resampling since: 5248.085111766085
# resampling since: 5984.770034587279
# resampling since: 4070.4026384309896
# resampling since: 6089.040944464
# resampling since: 6867.365688711063
# resampling since: 5261.657264038946
# resampling since: 6913.026983014999
# resampling since: 6459.583610820942
# resampling since: 5742.442551524961
# resampling since: 3489.3404099519926
# resampling since: 5379.19802229719
# resampling since: 6668.039711799377
# resampling since: 5474.752656964608
# resampling since: 5637.738911919928
# resampling since: 3417.410055559611
# resampling since: 6285.8571551372315
# resampling since: 4226.74354536146
# resampling since: 6561.875797745942
# resampling since: 6332.127343847388
# resampling since: 6956.25473304904
# resampling since: 4728.590286900157
# resampling since: 5758.263843087498
# resampling since: 3391.056609568564
# resampling since: 4676.513720592153
# resampling since: 4970.426526712271
# resampling since: 5468.429601472174
# resampling since: 6553.51406010816
# resampling since: 6501.802933928358
# resampling since: 6578.917586012436
# resampling since: 6124.732388747134
# resampling since: 6553.5085058710565
# resampling since: 6899.150471624974
# resampling since: 4774.467446046167
# resampling since: 6763.8633081848475
# resampling since: 5729.609144161042
# resampling since: 6891.650998313421
# resampling since: 6948.106676520475
# resampling since: 4398.208327561038
# resampling since: 5273.541484029056
# resampling since: 6887.027380608709
# resampling since: 6459.39528531095
# resampling since: 5757.329503014155
# resampling since: 5397.603203508662
# resampling since: 6823.9400079315255
# resampling since: 6303.035534854249
# resampling since: 6920.451375938877
# resampling since: 5909.847436618468
# resampling since: 6193.305503117687
# resampling since: 5827.414180876557
# resampling since: 4374.470565893925
# resampling since: 5317.820352618125
# resampling since: 6688.10504503941
# resampling since: 5887.997655094671
# resampling since: 6277.314099396291
# resampling since: 6973.210592095656
# resampling since: 6851.117945608206
# resampling since: 6707.304418179716
# resampling since: 6812.173219258582
# resampling since: 6101.121026598818
# resampling since: 5034.381412352788
# resampling since: 5843.798072927423
# resampling since: 4425.125331292377
# resampling since: 5489.810047004678
# resampling since: 5431.097157657425
# resampling since: 6926.626895077035
# resampling since: 5574.854525423613
# resampling since: 6157.134156282557
# resampling since: 4834.942283570559
# resampling since: 5077.11417967222
# resampling since: 5937.606412363767
# resampling since: 2354.857261843976
# resampling since: 6726.157567756968
# resampling since: 5389.834086820528
# resampling since: 2136.6267745730474
# resampling since: 6861.007335489232
# resampling since: 6659.185758266637
# resampling since: 6941.667971845181
# resampling since: 921.6388873019449
# resampling since: 700.1974454324967
# resampling since: 4805.597441856729
# resampling since: 1665.8204976761517
# resampling since: 6439.782237858234
# resampling since: 4116.92745560327
# resampling since: 6330.988320075748
# resampling since: 6051.5048167163095
# resampling since: 6751.440896010014
# resampling since: 5839.443950616534
# resampling since: 6750.482147103644
# resampling since: 6854.4063333743225
# resampling since: 5853.123224946585
# resampling since: 5667.220974612546
# resampling since: 6316.527079474757
# resampling since: 6227.696216900675
# resampling since: 3157.466235521581
# resampling since: 6935.137217323002
# resampling since: 5354.592849894738
# resampling since: 6849.322916790108
# resampling since: 6953.355037664558
# resampling since: 6494.395528034674
# resampling since: 5776.696782222379
# resampling since: 6182.6045442054965
# resampling since: 6294.858774738892
# resampling since: 4862.25642379788
# resampling since: 6939.65502801743
# resampling since: 6352.818383105822
# resampling since: 5011.257197884337
# resampling since: 6520.218238586349
# resampling since: 6997.7163511347335
# resampling since: 5393.395598416029
# resampling since: 5221.964693435646
# resampling since: 6742.018876545552
# resampling since: 6522.708158273582
# resampling since: 6796.533590631652
# resampling since: 6310.394316368545
# resampling since: 4850.397738730472
# resampling since: 4572.260352208103
# resampling since: 6844.61301773609
# resampling since: 6087.591410953601
# resampling since: 6347.078624748173
# resampling since: 6612.429368942098
# resampling since: 6363.37169934768
# resampling since: 5893.537205089539
# resampling since: 6923.8692236788265
# resampling since: 6847.953840095521
# resampling since: 6999.275963449996
# resampling since: 6073.7185444497245
# resampling since: 6656.750912919507
# resampling since: 6595.324559728686
# resampling since: 6471.780438901039
# resampling since: 6697.691199753756
# resampling since: 2490.7031290970017
# resampling since: 5616.561769345028
# resampling since: 6861.760106570531
# resampling since: 6159.996982374663
# resampling since: 6976.849778210131
# resampling since: 6217.697862960883
# resampling since: 4659.406514546858
# resampling since: 6339.746032480267
# resampling since: 6475.726520554279
# resampling since: 6672.592578313778
# resampling since: 6144.640137901668
# resampling since: 2366.121765036029
# resampling since: 6487.5977671771825
# resampling since: 6335.676711622179
# resampling since: 6669.742474047986
# resampling since: 6763.562615904398
# resampling since: 6768.641824871606
# resampling since: 5852.237081880352
# resampling since: 6687.589937223258
# resampling since: 2101.8003650249693
# resampling since: 4752.3710868137905
# resampling since: 5579.325049520456
# resampling since: 6961.118327381993
# resampling since: 6250.1166521536
# resampling since: 4924.582185341607
# resampling since: 5824.983198458362
# resampling since: 4459.565093292339
# resampling since: 3970.9056646187573
# resampling since: 4780.183730632493
# resampling since: 6331.928675994548
# resampling since: 6865.313907477267
# resampling since: 5544.65990659947
# resampling since: 6571.376125268613
# resampling since: 5466.273217926121
# resampling since: 6898.1934634077725
# resampling since: 6840.3777811899845
# resampling since: 6828.281019616817
# resampling since: 5634.00539756544
# resampling since: 6358.383480747923
# resampling since: 6332.091861922707
# resampling since: 5036.278453858965
# resampling since: 4906.200701588023
# resampling since: 6749.422876080923
# resampling since: 6446.405935086176
# resampling since: 6169.121406923007
# resampling since: 6130.946489482399
# resampling since: 6761.806662633455
# resampling since: 6313.44662722708
# resampling since: 4444.878496101081
# resampling since: 6220.766030036803
# resampling since: 6365.822760599064
# resampling since: 6445.130903694634
# resampling since: 6460.597200357764
# resampling since: 5631.367143294905
# resampling since: 6780.717222672611
# resampling since: 6987.753926277696
# resampling since: 6842.058809431572
# resampling since: 5731.001395638469
# resampling since: 5923.333488379102
# resampling since: 6269.41257592382
# resampling since: 5077.689687562038
# resampling since: 5850.138158976482
# resampling since: 5721.15642226251
# resampling since: 6087.4239442888165
# resampling since: 5648.918520509354
# resampling since: 6228.150162231973
# resampling since: 2815.514000557525
# resampling since: 6429.961068515449
# resampling since: 6427.863988705537
# resampling since: 3136.942521818894
# resampling since: 6619.864850384694
# resampling since: 6476.103998185781
# resampling since: 5348.945358126547
# resampling since: 4830.675064472412
# resampling since: 3996.845404965481
# resampling since: 6507.898011373474
# resampling since: 6307.715915267304
# resampling since: 5767.820996438019
# resampling since: 1322.3970719061167
# resampling since: 6750.6654039747755
# resampling since: 3640.6771352912315
# resampling since: 5536.9384324984985
# resampling since: 4516.855721925703
# resampling since: 6012.383738208103
# resampling since: 6543.067763109511
# resampling since: 4798.92544994692
# resampling since: 6097.573581183673
# resampling since: 6874.0307801829495
# resampling since: 5307.967850276944
# resampling since: 6541.949445737342
# resampling since: 3938.644500829582
# resampling since: 6337.69741383837
# resampling since: 6297.455377094789
# resampling since: 5770.122072085925
# resampling since: 5552.845761771017
# resampling since: 6349.539542099819
# resampling since: 4880.654211511756
# resampling since: 5792.433063614138
# resampling since: 3127.422891910877
# resampling since: 4316.652615348618
# resampling since: 4822.982688881193
# resampling since: 5108.31152018381
# resampling since: 3751.0763250060045
# resampling since: 6610.008842289331
# resampling since: 2125.4654822504986
# resampling since: 2908.1420295538956
# resampling since: 5946.847641638297
# resampling since: 3773.051496112527
# resampling since: 3072.346526819273
# resampling since: 6361.8026453966695
# resampling since: 6605.007939481532
# resampling since: 6758.895213298056
# resampling since: 6811.252301718863
# resampling since: 5605.192118744299
# resampling since: 6539.0005196870125
# resampling since: 6830.030904885701
# resampling since: 6012.91814013271
# resampling since: 5231.449606688006
# resampling since: 6958.55552424915
# resampling since: 6343.79971065534
# resampling since: 6950.409603768142
# resampling since: 6909.81441383904
# resampling since: 5295.338366400673
# resampling since: 6460.464878181775
# resampling since: 6512.423886257669
# resampling since: 6969.472037322395
# resampling since: 4404.434695429099
# resampling since: 6324.935671737656
# resampling since: 6414.47504278946
# resampling since: 6629.552229574647
# resampling since: 5782.088754054144
# resampling since: 5823.321210849535
# resampling since: 6542.698004752065
# resampling since: 2823.26673430982
# resampling since: 6728.828036487048
# resampling since: 2977.508995526825
# resampling since: 6086.825809118633
# resampling since: 6237.445576993328
# resampling since: 6058.3227156839985
# resampling since: 6079.929667527662
# resampling since: 3621.9145487861424
# resampling since: 6297.48046826064
# resampling since: 4156.189765560183
# resampling since: 5042.389286802325
# resampling since: 6429.750401763997
# resampling since: 6452.937593885091
# resampling since: 4348.231249630675
# resampling since: 4478.844144450124
# resampling since: 6943.665364885651
# resampling since: 2531.7132398243416
# resampling since: 6968.851981682865
# resampling since: 6860.365567314062
# resampling since: 6049.2078579715635
# resampling since: 6411.344866269938
# resampling since: 6811.67031583923
# resampling since: 6895.616777849143
# resampling since: 6673.827755079159
# resampling since: 6262.248915349886
# resampling since: 6198.657226139715
# resampling since: 6161.961422921375
# resampling since: 6473.122208792785
# resampling since: 6016.053994447322
# resampling since: 5972.424960068358
# resampling since: 5271.10126525026
# resampling since: 3364.1059769839644
# resampling since: 6985.721231631395
# resampling since: 6119.15311664539
# resampling since: 3717.2199964216043
# resampling since: 3828.9399362731046
# resampling since: 6792.149285919831
# resampling since: 6418.691246039883
# resampling since: 5476.224755806699
# resampling since: 5670.261609160687
# resampling since: 5056.207955292
# resampling since: 2166.6757399422368
# resampling since: 6520.780422907879
# resampling since: 6804.465014704995
# resampling since: 3664.670302799128
# resampling since: 5373.438771377451
# resampling since: 6682.107666533261
# resampling since: 6981.951411151267
# resampling since: 5045.9004353177115
# resampling since: 1351.7595006007678
# resampling since: 6132.714586683282
# resampling since: 2647.282395629351
# resampling since: 6159.042506633914
# resampling since: 3243.819249341296
# resampling since: 5572.947554424002
# resampling since: 4956.9034052784955
# resampling since: 2800.355122445434
# resampling since: 6535.354800594532
# resampling since: 6496.358388938333
# resampling since: 4838.76430040212
# resampling since: 6022.930149704153
# resampling since: 6612.696170155162
# resampling since: 6353.302196115314
# resampling since: 2657.3649821685212
# resampling since: 1197.1857324015318
# resampling since: 5897.808966111058
# resampling since: 3264.6816820431895
# resampling since: 6609.877139004175
# resampling since: 3373.453286953402
# resampling since: 5914.548706847648
# resampling since: 6665.980685740989
# resampling since: 6252.12824784352
# resampling since: 6324.6817662961585
# resampling since: 6303.073498461027

# %%
pf_heston_test = PFHeston(test_returns, N=10000, dt=1/252, is_log=True)

V_pf_train, _ = pf_heston_train.filter([*param_bounds, V0], predict_obs=False)
V_pf_test, _ = pf_heston_test.filter([*param_bounds, V_pf_train[-1]], predict_obs=False)
# Out:
# resampling since: 6439.765590348835
# resampling since: 4878.946893272386
# resampling since: 5649.853150462656
# resampling since: 6606.375199112974
# resampling since: 6110.601530206066
# resampling since: 6289.272324541185
# resampling since: 6278.360250493629
# resampling since: 6179.707841615585
# resampling since: 4877.8444875760315
# resampling since: 6113.203164718602
# resampling since: 6384.877599037182
# resampling since: 6147.95645114666
# resampling since: 5474.344021565389
# resampling since: 1944.3646135823144
# resampling since: 6237.001264155177
# resampling since: 6661.655495396528
# resampling since: 6663.286959929646
# resampling since: 6601.3474164363515
# resampling since: 6238.155842782421
# resampling since: 6503.648513475902
# resampling since: 5847.05776791344
# resampling since: 4903.705311773027
# resampling since: 5843.8027004230225
# resampling since: 6172.053736076881
# resampling since: 6248.0527099271385
# resampling since: 4180.145177923865
# resampling since: 5472.3456638304315
# resampling since: 4182.003613057255
# resampling since: 1118.8229322572429
# resampling since: 2480.574351676153
# resampling since: 4760.290515746591
# resampling since: 6091.937310773234
# resampling since: 5957.588835349874
# resampling since: 4804.913043242735
# resampling since: 5232.628616973953
# resampling since: 4704.094043127057
# resampling since: 4292.3920096498705
# resampling since: 6655.111531535923
# resampling since: 6572.634007318576
# resampling since: 4298.134311081063
# resampling since: 6492.137029329972
# resampling since: 6468.736304555918
# resampling since: 6211.762924552471
# resampling since: 6571.354244442017
# resampling since: 5740.775093433462
# resampling since: 5959.813297883882
# resampling since: 6563.7901561159115
# resampling since: 3677.9159116494247
# resampling since: 6415.828223223729
# resampling since: 3152.2239770959745
# resampling since: 5015.206140679262
# resampling since: 6475.8934935131265
# resampling since: 6851.080842911162
# resampling since: 5432.246126331207
# resampling since: 6282.2861017613295
# resampling since: 6756.624308541655
# resampling since: 5767.528967527068
# resampling since: 5945.215574982442
# resampling since: 6806.517835997357
# resampling since: 5986.034667706035
# resampling since: 5174.34286679637
# resampling since: 6408.610792646217
# resampling since: 6604.137661070008
# resampling since: 4912.487487340296
# resampling since: 4332.33044635176
# resampling since: 4377.249994037314
# resampling since: 6895.505504138801
# resampling since: 6290.854460137851
# resampling since: 4200.080887873511
# resampling since: 6464.711821747859
# resampling since: 6177.8855089022545
# resampling since: 6487.34354278507
# resampling since: 5785.999292262303
# resampling since: 6373.383063961325
# resampling since: 5939.396290545548
# resampling since: 5806.894548568848
# resampling since: 6862.714770716162
# resampling since: 5451.826088703786
# resampling since: 1053.952195334386
# resampling since: 4222.697689656471
# resampling since: 6820.264747734675
# resampling since: 5970.329065152347
# resampling since: 6002.662453582528
# resampling since: 6028.520962182914
# resampling since: 4208.1585665407565
# resampling since: 4165.693994317137
# resampling since: 5118.089214323558
# resampling since: 2296.947203873153
# resampling since: 3685.502590630735
# resampling since: 6507.969358162526
# resampling since: 6837.750732166564
# resampling since: 1557.2733013768595
# resampling since: 5173.496472515614
# resampling since: 6593.703981917216
# resampling since: 6802.5616669472365
# resampling since: 5648.092681942151
# resampling since: 4568.314143656986
# resampling since: 6722.707594574001
# resampling since: 5718.572811048231
# resampling since: 845.1433128715593
# resampling since: 5278.442265270897
# resampling since: 2722.451483072758
# resampling since: 4456.20509848917
# resampling since: 4977.459277676346
# resampling since: 6559.346124596038
# resampling since: 6549.867982494225
# resampling since: 5257.012061597166
# resampling since: 6874.185791697403
# resampling since: 5795.108596521232
# resampling since: 6565.867024266347
# resampling since: 6620.1929152995035
# resampling since: 6577.193422397897
# resampling since: 6552.413979409068
# resampling since: 4244.9624763438005
# resampling since: 6817.974181235662
# resampling since: 5935.796680486118
# resampling since: 5402.461867336474
# resampling since: 6963.219816403027
# resampling since: 6682.641622966606
# resampling since: 5769.811462069557
# resampling since: 6518.733789742701
# resampling since: 6781.059461686815
# resampling since: 6977.799191987011
# resampling since: 6946.702051932917
# resampling since: 5892.9799139148845
# resampling since: 3417.590401635397
# resampling since: 5348.134824640763
# resampling since: 5306.458040064647
# resampling since: 5885.967155209089
# resampling since: 6257.529651909135
# resampling since: 6721.627791642899
# resampling since: 6944.956824149988
# resampling since: 6783.245247792184
# resampling since: 5198.287081560309
# resampling since: 5233.4297863898255
# resampling since: 6063.75988229595
# resampling since: 5000.433716477564
# resampling since: 5203.799492138546
# resampling since: 6912.547210717005
# resampling since: 6784.1301500792515
# resampling since: 6809.76052710279
# resampling since: 5410.172462194811
# resampling since: 6051.503700282756
# resampling since: 6041.202361013213
# resampling since: 2517.0501225348708
# resampling since: 6615.2410357742965
# resampling since: 3487.6066331340207
# resampling since: 6957.349296542244
# resampling since: 5724.018301328612
# resampling since: 6094.744332792904
# resampling since: 5896.286410359924
# resampling since: 6114.020411404114
# resampling since: 6305.650273368051
# resampling since: 4491.568254595283
# resampling since: 4108.061675018243
# resampling since: 2399.027998260395
# resampling since: 5663.7407356456315
# resampling since: 1929.2850489768007
# resampling since: 6327.388906016905
# resampling since: 6741.5467660636605
# resampling since: 6877.830684301888
# resampling since: 6707.668328830533
# resampling since: 5494.43249180362
# resampling since: 4618.52929302756
# resampling since: 4744.358898445365
# resampling since: 4374.211150751463
# resampling since: 6914.749964686937
# resampling since: 5526.4302861549895
# resampling since: 6389.071249843489
# resampling since: 5239.869190940428
# resampling since: 5438.284740824287
# resampling since: 5259.689614374066
# resampling since: 6760.054372310229
# resampling since: 6070.447022277017
# resampling since: 6554.74710175502
# resampling since: 6305.159999086127
# resampling since: 5422.21758650247
# resampling since: 5771.3124614375365
# resampling since: 5727.405414355309
# resampling since: 6654.442283443758
# resampling since: 6808.444810698378
# resampling since: 6690.29527345218
# resampling since: 6443.843568527051
# resampling since: 6773.722102694636
# resampling since: 6121.156843977811
# resampling since: 5608.602369577075
# resampling since: 5071.9244630343765
# resampling since: 6923.638803017275
# resampling since: 2866.15234537858
# resampling since: 4733.272076033027
# resampling since: 5566.788926069104
# resampling since: 6459.64280248803
# resampling since: 5807.44603616053
# resampling since: 4695.840549149865
# resampling since: 5978.745778876978
# resampling since: 3616.8112737962897
# resampling since: 2871.8166746958295
# resampling since: 6381.038091640151
# resampling since: 6605.969344487746
# resampling since: 3566.63943414782
# resampling since: 6690.166640596694
# resampling since: 6834.965452987339
# resampling since: 3044.963208715617
# resampling since: 6600.0368861668285
# resampling since: 6355.622568622944
# resampling since: 6996.3701646104655
# resampling since: 6490.9658632749915
# resampling since: 5927.138768590098
# resampling since: 6457.466359175061
# resampling since: 4334.688812755121
# resampling since: 2877.6081268514276
# resampling since: 6390.344355188882
# resampling since: 6823.177374857719
# resampling since: 6014.725307718576
# resampling since: 5772.884470752766
# resampling since: 6727.306148164874
# resampling since: 4940.795953068531
# resampling since: 6846.937168166252
# resampling since: 5765.652409440211
# resampling since: 6696.509739768842
# resampling since: 4415.441941313999
# resampling since: 4472.274211904209
# resampling since: 6649.114590219463
# resampling since: 4947.180722118751
# resampling since: 6107.087561759425
# resampling since: 5750.3953837850895
# resampling since: 5193.718813174998
# resampling since: 3624.6874938768624
# resampling since: 6911.977829492543
# resampling since: 3814.0949235270746
# resampling since: 4305.64758624758
# resampling since: 4273.343030670119
# resampling since: 3976.0727346068657
# resampling since: 3633.743569044263
# resampling since: 4856.376212665048
# resampling since: 6562.198490865374
# resampling since: 3177.5362005988673
# resampling since: 4367.397231871384
# resampling since: 2978.1911083562136
# resampling since: 6792.263712194793
# resampling since: 6215.315549332002
# resampling since: 5890.268959148101
# resampling since: 5924.218439738436
# resampling since: 5797.82428225022
# resampling since: 6975.408528984902
# resampling since: 4269.794053224821
# resampling since: 6963.974558318096
# resampling since: 5933.122281902426
# resampling since: 6878.6793490051605
# resampling since: 6533.643516392127
# resampling since: 6939.549989629963
# resampling since: 5933.047316479246
# resampling since: 6234.329998263019
# resampling since: 6748.1492246934795
# resampling since: 6881.111390053196
# resampling since: 6703.50383213754
# resampling since: 6172.962873941375
# resampling since: 6172.8453051732895
# resampling since: 6998.572576932883
# resampling since: 4881.33741040199
# resampling since: 3409.543561052064
# resampling since: 6543.999294906191
# resampling since: 6063.780466113985
# resampling since: 4576.27031047665
# resampling since: 6939.507632703793
# resampling since: 6043.458220683711
# resampling since: 6172.840207795362
# resampling since: 5931.463250822929
# resampling since: 6225.827335918437
# resampling since: 6429.814085353653
# resampling since: 6279.644757630395
# resampling since: 6780.437884517714
# resampling since: 5434.6342528673285
# resampling since: 3313.4171420112602
# resampling since: 6442.983016585022
# resampling since: 3599.4135778824207
# resampling since: 5864.405068848603
# resampling since: 5640.210824265062
# resampling since: 6530.593683003133
# resampling since: 3850.3627039406074
# resampling since: 6730.037246279877
# resampling since: 6675.63497496773
# resampling since: 2342.331947859597
# resampling since: 4450.131920529551
# resampling since: 6170.543509551347
# resampling since: 6317.932875876012
# resampling since: 6246.140419090743
# resampling since: 5865.182116722914
# resampling since: 5906.661893036243
# resampling since: 6002.964565659337
# resampling since: 5618.662810784859
# resampling since: 5490.769465736221
# resampling since: 5443.739351913287
# resampling since: 6665.845679954271
# resampling since: 5016.426676156166
# resampling since: 6467.532968503311
# resampling since: 6520.392864380975
# resampling since: 4342.402197521198
# resampling since: 4633.043658497916
# resampling since: 6053.103156651501
# resampling since: 6014.964557779592
# resampling since: 4703.827685895369
# resampling since: 5630.762463464107
# resampling since: 6397.74935880858
# resampling since: 6499.671533550045
# resampling since: 6879.61988943143
# resampling since: 5634.684486758158
# resampling since: 5891.61751900796
# resampling since: 6794.781749591018
# resampling since: 4226.437532670817
# resampling since: 4830.773506333747
# resampling since: 6779.493159708157
# resampling since: 6620.667371581534
# resampling since: 6076.826010884972
# resampling since: 5869.9195924828055
# resampling since: 6847.929391298544
# resampling since: 6364.673325977026
# resampling since: 6549.907192928377
# resampling since: 6844.826523861959
# resampling since: 6605.839468599142
# resampling since: 6953.643794221528
# resampling since: 4151.475545745085
# resampling since: 5804.524548455744
# resampling since: 3790.2170977661594
# resampling since: 5113.384781512935
# resampling since: 4344.0848506508755
# resampling since: 6980.2905132065525
# resampling since: 6921.363408509568
# resampling since: 5475.190590678316
# resampling since: 3254.1061526912504
# resampling since: 4559.754436203114
# resampling since: 5519.39989087238
# resampling since: 5457.385862251991
# resampling since: 6953.188263391217
# resampling since: 6993.915579041876
# resampling since: 5311.9407822673365
# resampling since: 6741.843115342715
# resampling since: 2718.620419194192
# resampling since: 6145.640463410947
# resampling since: 6305.629649853167
# resampling since: 5996.6661210638995
# resampling since: 392.28098447936776
# resampling since: 496.3292152700128
# resampling since: 4444.3421308895195
# resampling since: 1792.7091253996784
# resampling since: 5536.386944772213
# resampling since: 3524.181601011636
# resampling since: 5780.872829318866
# resampling since: 6424.9878331218815
# resampling since: 5763.647951637123
# resampling since: 6310.790708768013
# resampling since: 6212.667476702927
# resampling since: 5257.435200310179
# resampling since: 5804.862126722935
# resampling since: 6881.961292025755
# resampling since: 6599.182489968174
# resampling since: 5337.533485797583
# resampling since: 4553.414381036173
# resampling since: 6524.289961843941
# resampling since: 5417.890151309014
# resampling since: 4634.0340664243395
# resampling since: 6873.699893279305
# resampling since: 3548.0349410460058
# resampling since: 6343.466075274525
# resampling since: 5950.546340798354
# resampling since: 6814.071720117684
# resampling since: 6401.395223751374
# resampling since: 6524.037393494399
# resampling since: 6451.428834819362
# resampling since: 4752.229995844467
# resampling since: 4769.346837464801
# resampling since: 3661.495243517101
# resampling since: 6738.691049840799
# resampling since: 4813.348283920383
# resampling since: 3877.0113780139914
# resampling since: 6935.453406350141
# resampling since: 5415.356826176389
# resampling since: 5182.650351704878
# resampling since: 4364.787571815327
# resampling since: 5385.235410034871
# resampling since: 4678.519103826295
# resampling since: 6934.394538813747
# resampling since: 6370.153629757162
# resampling since: 6723.535042094076
# resampling since: 6217.1569816785
# resampling since: 3425.8464201159304
# resampling since: 2670.3122495701787
# resampling since: 6925.328983384076
# resampling since: 4904.629515453127
# resampling since: 5864.527986901109
# resampling since: 6861.040875079781
# resampling since: 5833.433923225371
# resampling since: 5959.823231081018
# resampling since: 6799.695886361653
# resampling since: 6671.341250078179
# resampling since: 5638.981116278702
# resampling since: 5567.217856959622
# resampling since: 5355.406395530921
# resampling since: 6765.402274107367
# resampling since: 5871.661724176378
# resampling since: 6113.361241324355
# resampling since: 6893.687774818939
# resampling since: 6829.346223095926
# resampling since: 6364.259211788415
# resampling since: 6444.946934070255
# resampling since: 5494.713628908024
# resampling since: 2207.770759082151
# resampling since: 4979.214708888648
# resampling since: 6744.648844808961
# resampling since: 6107.758729145212
# resampling since: 6033.066305793391
# resampling since: 6425.259621124161
# resampling since: 6772.776358017995
# resampling since: 4133.807930653447
# resampling since: 5958.343061104313
# resampling since: 6860.247382127077
# resampling since: 5673.704565625481
# resampling since: 5964.715679614763
# resampling since: 5025.294894780801
# resampling since: 6139.464896990505
# resampling since: 2656.4403433147386
# resampling since: 5791.2040163492775
# resampling since: 5334.084605799619
# resampling since: 5791.131879887895
# resampling since: 6956.79620869294
# resampling since: 6751.44214346776
# resampling since: 5577.009679309995
# resampling since: 6477.023052650365
# resampling since: 6682.290242404297
# resampling since: 1666.2805468915165
# resampling since: 4644.07319393417
# resampling since: 6510.408607539903
# resampling since: 5556.040912967674
# resampling since: 6881.4266380857935
# resampling since: 6431.590540803803
# resampling since: 6927.9287942019
# resampling since: 2548.449498902416
# resampling since: 6436.467320856178
# resampling since: 3419.446135468095
# resampling since: 3142.79122665996
# resampling since: 3857.2092386945465
# resampling since: 6846.2153533082965
# resampling since: 4307.2763559147825
# resampling since: 5192.0827175953045
# resampling since: 5703.574633482693
# resampling since: 4676.124798006549
# resampling since: 6907.4486042720255
# resampling since: 6740.1706232548995
# resampling since: 6009.216943104709
# resampling since: 4540.470638868022
# resampling since: 5906.024399782497
# resampling since: 6395.099047500353
# resampling since: 6760.60610616414
# resampling since: 6401.901188080764
# resampling since: 4923.717393705087
# resampling since: 3763.6075697868946
# resampling since: 5882.930859611158
# resampling since: 5624.943891264387
# resampling since: 6903.263925876631
# resampling since: 6734.860385918391
# resampling since: 4993.263814567497
# resampling since: 6657.48025054706
# resampling since: 6031.031101928511
# resampling since: 4174.668817692405
# resampling since: 5791.793379186846
# resampling since: 6891.730602690491
# resampling since: 5721.256710985206
# resampling since: 6759.370143270628
# resampling since: 6946.475212849812
# resampling since: 6254.01463708163
# resampling since: 6942.680932060473
# resampling since: 6522.795516305443
# resampling since: 6782.900006114552
# resampling since: 6560.098342915531
# resampling since: 6982.255289139764
# resampling since: 6283.972015012371
# resampling since: 5062.06805833481
# resampling since: 6951.751558609156
# resampling since: 6493.745006419717
# resampling since: 5795.837688144186
# resampling since: 5634.950721747236
# resampling since: 6820.341716720005
# resampling since: 6468.693912288069
# resampling since: 5250.832779716718
# resampling since: 4536.8496757803905
# resampling since: 6163.47194497926
# resampling since: 3071.557330775548
# resampling since: 6324.138726648306
# resampling since: 6256.586206688599
# resampling since: 6985.492416756507
# resampling since: 4175.009220516162
# resampling since: 6266.057040128654
# resampling since: 5662.535654834723
# resampling since: 5495.296234593448
# resampling since: 4458.307592971501
# resampling since: 3752.8596183644513
# resampling since: 6321.958962573529
# resampling since: 4187.747524334978
# resampling since: 5216.286163338096
# resampling since: 1619.865542425944
# resampling since: 6419.596873619066
# resampling since: 2498.495901415492
# resampling since: 5232.334893774856
# resampling since: 4660.337162683192
# resampling since: 5976.7123804519615
# resampling since: 6539.434356607575
# resampling since: 4323.132329685964
# resampling since: 6782.987332564478
# resampling since: 4711.427265905369
# resampling since: 5838.822944176464
# resampling since: 6095.400104183138
# resampling since: 3689.649598101223
# resampling since: 6987.544893455614
# resampling since: 6392.386675425047
# resampling since: 6424.1810214704865
# resampling since: 5232.189142141888
# resampling since: 6203.482284650431
# resampling since: 4689.911224140124
# resampling since: 6752.666944455367
# resampling since: 3025.475996707525
# resampling since: 3596.27439361296
# resampling since: 5232.018878458748
# resampling since: 5236.069667105335
# resampling since: 3983.744733278831
# resampling since: 6681.506053160548
# resampling since: 2402.286353512279
# resampling since: 3210.26910903379
# resampling since: 5886.117178317029
# resampling since: 4041.0186660615327
# resampling since: 3593.344114931338
# resampling since: 6068.718077693276
# resampling since: 6576.205490284161
# resampling since: 6732.812700933772
# resampling since: 6072.901562107581
# resampling since: 6215.016308495877
# resampling since: 6546.381820850969
# resampling since: 6682.171128030847
# resampling since: 6381.235281850736
# resampling since: 5339.966961053796
# resampling since: 6811.833142725254
# resampling since: 6586.043007183997
# resampling since: 6922.424389319542
# resampling since: 5400.86827278623
# resampling since: 6859.409998188885
# resampling since: 6517.964570082339
# resampling since: 6288.316610911088
# resampling since: 4142.740147320361
# resampling since: 6565.187618644309
# resampling since: 6670.08201986534
# resampling since: 6741.305865009118
# resampling since: 6069.368802700414
# resampling since: 5910.415317608744
# resampling since: 6816.462002131847
# resampling since: 3464.0337733233955
# resampling since: 6749.25995532375
# resampling since: 2770.197351399083
# resampling since: 6972.255610433662
# resampling since: 6996.395644214518
# resampling since: 6842.406190154156
# resampling since: 5432.1046256892205
# resampling since: 5863.349109144971
# resampling since: 3718.1171139477287
# resampling since: 6627.57625517837
# resampling since: 4894.399211186746
# resampling since: 5112.122207588099
# resampling since: 6530.084847061413
# resampling since: 6656.38432958177
# resampling since: 5552.866542132046
# resampling since: 4470.600433571507
# resampling since: 2717.1581242229186
# resampling since: 6665.730840468662
# resampling since: 6537.220226233562
# resampling since: 6559.648865687099
# resampling since: 6199.833155902717
# resampling since: 6638.07083372478
# resampling since: 6632.895329568402
# resampling since: 6644.227122024362
# resampling since: 6171.327499119863
# resampling since: 6547.346191504743
# resampling since: 6361.745591022084
# resampling since: 6806.155325650414
# resampling since: 5598.2930653069225
# resampling since: 6025.499998968934
# resampling since: 5671.386765747065
# resampling since: 2819.387153850699
# resampling since: 6999.203470436604
# resampling since: 6984.616970283462
# resampling since: 4138.244527731046
# resampling since: 4006.406853235868
# resampling since: 6783.011998401144
# resampling since: 6556.379017972579
# resampling since: 5278.443530995508
# resampling since: 5290.892404971752
# resampling since: 4903.938667725619
# resampling since: 2006.7405300606772
# resampling since: 6475.390031828532
# resampling since: 6555.351513162815
# resampling since: 4600.08499388865
# resampling since: 5286.641709499946
# resampling since: 6191.365053388157
# resampling since: 6587.179956305179
# resampling since: 4886.293019958731
# resampling since: 925.9318650794243
# resampling since: 6938.378025114368
# resampling since: 2911.5069312859414
# resampling since: 6281.071582278093
# resampling since: 3853.2570045812627
# resampling since: 6649.974082754213
# resampling since: 5219.664905841548
# resampling since: 2063.7173777820444
# resampling since: 6815.571304773158
# resampling since: 6486.038370731465
# resampling since: 4892.33796496866
# resampling since: 5855.590720525097
# resampling since: 6899.271786379476
# resampling since: 6179.5309606406045
# resampling since: 2718.1251461566135
# resampling since: 1395.219001491416
# resampling since: 6491.157317273476
# resampling since: 3481.2660054867365
# resampling since: 6685.9655209110615
# resampling since: 4380.402653609209
# resampling since: 5657.142982742652
# resampling since: 6988.7146464831885
# resampling since: 6466.536989060139
# resampling since: 6668.360501638587
# resampling since: 6430.27931935748
# resampling since: 6312.4292810020315
# resampling since: 6243.837323056414
# resampling since: 6064.504238636848
# resampling since: 6492.675079926747
# resampling since: 6485.281475674856
# resampling since: 5669.863320641106
# resampling since: 6962.2414501387375
# resampling since: 6724.643959370716
# resampling since: 6707.331657844639
# resampling since: 5091.541000204077
# resampling since: 3188.4598198148387
# resampling since: 1702.1722179839217
# resampling since: 6010.101471129939
# resampling since: 6802.332288274781
# resampling since: 5399.954204331433
# resampling since: 6385.717059384282
# resampling since: 6689.105949019243
# resampling since: 3373.197923536511
# resampling since: 5406.643668709049
# resampling since: 6782.600284460578
# resampling since: 6158.063466542169
# resampling since: 6934.389069367693
# resampling since: 6778.822600774773
# resampling since: 6429.578287451296
# resampling since: 5135.935356123711
# resampling since: 6845.723655225744
# resampling since: 6835.103317827299
# resampling since: 6863.440631176215
# resampling since: 6056.489872877436
# resampling since: 4001.354546628959
# resampling since: 6932.768974053282
# resampling since: 6641.842071099084
# resampling since: 6554.845008141963
# resampling since: 5696.938728979502
# resampling since: 6851.900146252083
# resampling since: 5742.9881100544635
# resampling since: 6994.610332514122
# resampling since: 6034.712872042679
# resampling since: 3934.768121447072
# resampling since: 3821.1944873934035
# resampling since: 6203.601167304954
# resampling since: 6375.660679356586
# resampling since: 6983.420333396086
# resampling since: 6596.9759661433645
# resampling since: 5145.797107351644
# resampling since: 6206.0423467711025
# resampling since: 6921.1573709881195
# resampling since: 6654.290447796256
# resampling since: 6882.22882473656
# resampling since: 4966.885199993961
# resampling since: 5551.966451973593
# resampling since: 6539.541945918032
# resampling since: 6813.80683802806
# resampling since: 4339.553817246147
# resampling since: 5689.964896664434
# resampling since: 6733.0325289015245
# resampling since: 3784.820869903175
# resampling since: 4555.124185227141
# resampling since: 5058.747663156191
# resampling since: 3005.617513060614
# resampling since: 6895.438582695311
# resampling since: 4628.661013499652
# resampling since: 6124.527342614699
# resampling since: 6456.441869181622
# resampling since: 5973.915876772859
# resampling since: 6032.104010669748
# resampling since: 6682.527493896438
# resampling since: 6642.0127465740925
# resampling since: 5253.862645486176
# resampling since: 6487.351930233052
# resampling since: 5920.934503612233
# resampling since: 6036.821760701847
# resampling since: 6313.275601461433
# resampling since: 6976.586347521262
# resampling since: 1031.3371026615623
# resampling since: 3318.485665409139
# resampling since: 6395.876388477008
# resampling since: 5584.756324759244
# resampling since: 5975.801877783562
# resampling since: 6505.300019781613
# resampling since: 4451.921622174056
# resampling since: 4891.643127425496
# resampling since: 5067.960186806855
# resampling since: 6730.57411601253
# resampling since: 5666.411227299787
# resampling since: 1761.9550002619903
# resampling since: 4944.29582908969
# resampling since: 6526.209899434888
# resampling since: 6568.576676192201
# resampling since: 6236.300533659497
# resampling since: 4275.978366310603
# resampling since: 3866.2984839414203
# resampling since: 6239.585868410798
# resampling since: 6605.743268603671
# resampling since: 5294.370820157581
# resampling since: 4778.739232868174
# resampling since: 4863.369361505064
# resampling since: 6134.423731847898
# resampling since: 6402.537857835206
# resampling since: 5311.362833787305
# resampling since: 6546.879766022389
# resampling since: 4992.646566536508
# resampling since: 6814.080460507149
# resampling since: 6453.467365711863
# resampling since: 5129.717159123012
# resampling since: 6222.039136884043
# resampling since: 6721.982786911075
# resampling since: 6718.103356669335
# resampling since: 6012.886092150838
# resampling since: 6948.046559036461
# resampling since: 6432.268479186764
# resampling since: 5813.03162034384
# resampling since: 6633.9793168391725
# resampling since: 2047.4238964982526
# resampling since: 6582.571679503523
# resampling since: 6692.121205129561
# resampling since: 5593.280466363702
# resampling since: 4912.947414068738
# resampling since: 6429.865165811332
# resampling since: 5818.754896070833
# resampling since: 6642.029681772166
# resampling since: 6225.820410808865
# resampling since: 6181.216937446071
# resampling since: 4966.519702729397
# resampling since: 1569.2281170178167
# resampling since: 6725.472770604664
# resampling since: 5779.5509728948255
# resampling since: 6707.799916793766
# resampling since: 6983.832405182486
# resampling since: 2098.155501030141
# resampling since: 4845.98136760337
# resampling since: 5165.159907439423
# resampling since: 3726.4422803518946
# resampling since: 4660.148120720402
# resampling since: 6709.423650024138
# resampling since: 4929.177931070551
# resampling since: 6860.957947604732
# resampling since: 6650.424904465608
# resampling since: 5979.278097183392
# resampling since: 5693.707133620252
# resampling since: 6590.381303458029
# resampling since: 6594.034496053404
# resampling since: 6451.229470910249
# resampling since: 6683.478038413664
# resampling since: 6735.485450323485
# resampling since: 6085.863822542854
# resampling since: 2927.710137911231
# resampling since: 6802.336412490571
# resampling since: 5397.266552345413
# resampling since: 6063.479222261947
# resampling since: 4933.149134064467
# resampling since: 5196.397734189437
# resampling since: 5709.612039414068
# resampling since: 5372.962708980441
# resampling since: 6683.994650640251
# resampling since: 4549.639180366906
# resampling since: 5365.159922921146
# resampling since: 5891.642150430591
# resampling since: 6693.437971116523
# resampling since: 6987.055237660527
# resampling since: 5176.413857855599
# resampling since: 4251.6848622848665
# resampling since: 6192.901998963956
# resampling since: 6213.431933040441
# resampling since: 5850.96477887948
# resampling since: 4263.24660785681
# resampling since: 6057.281166896076
# resampling since: 5097.7095966365505
# resampling since: 3209.187595320203
# resampling since: 5348.101420553759
# resampling since: 6693.88972084288
# resampling since: 4845.169772296563
# resampling since: 5298.865748949996
# resampling since: 5653.9490150781785
# resampling since: 4259.261738914352
# resampling since: 6296.912778839451
# resampling since: 6328.773159858854
# resampling since: 6489.140681739698
# resampling since: 6396.212165235514
# resampling since: 6011.177787472112
# resampling since: 5220.476711914138
# resampling since: 6344.804241157844
# resampling since: 6652.100385180363
# resampling since: 2266.650633786785
# resampling since: 6290.243598437803
# resampling since: 6611.730328058976
# resampling since: 6563.254956196259
# resampling since: 6655.606654094659
# resampling since: 3932.4572918579934
# resampling since: 4287.590096167696
# resampling since: 6819.9460375776935
# resampling since: 5900.0586831091905
# resampling since: 5973.066202765596
# resampling since: 6922.806355512704
# resampling since: 6532.09330611266
# resampling since: 6822.710795738334
# resampling since: 3641.787503240706
# resampling since: 6961.040217333666
# resampling since: 6743.771004514426
# resampling since: 6911.186627158117
# resampling since: 6783.578366577682
# resampling since: 3721.523682822228
# resampling since: 6355.339642385312
# resampling since: 6205.242199840051
# resampling since: 6232.055452996228
# resampling since: 6436.129469096303
# resampling since: 2004.734221835383
# resampling since: 6710.7502729928365
# resampling since: 4301.665060367519
# resampling since: 2009.7174692908166
# resampling since: 3649.7185429432293
# resampling since: 6289.85001026364
# resampling since: 6097.011134890903
# resampling since: 3861.367987220546
# resampling since: 6257.834914426172
# resampling since: 4111.378488428978
# resampling since: 5648.460779225338
# resampling since: 5245.207342707929
# resampling since: 5309.801467535335
# resampling since: 5216.868944295138
# resampling since: 6992.192510821911
# resampling since: 5933.073949167002
# resampling since: 6110.747000119816
# resampling since: 6785.79834469159
# resampling since: 6689.437360260843
# resampling since: 3606.7391279590875
# resampling since: 6754.246259316798
# resampling since: 6708.69894402591
# resampling since: 5482.981137605809
# resampling since: 5702.69819234119
# resampling since: 6681.573971373481
# resampling since: 5759.561936909062
# resampling since: 6480.903703278339
# resampling since: 6799.201331346095
# resampling since: 5696.880708596482
# resampling since: 6735.776916657693
# resampling since: 4540.90092015452
# resampling since: 6681.925687855313
# resampling since: 6634.615017735994
# resampling since: 5248.452311516289
# resampling since: 6528.27832643885
# resampling since: 5250.431911802014
# resampling since: 2700.5953216453495
# resampling since: 5126.521725712999
# resampling since: 5179.943967291452
# resampling since: 5308.382046293722
# resampling since: 3289.0591240183744
# resampling since: 5570.3465545640565
# resampling since: 6795.107915163534
# resampling since: 6410.80493613917
# resampling since: 6145.976528343574
# resampling since: 5802.677859149937
# resampling since: 4605.379483108989
# resampling since: 6605.235850024072
# resampling since: 6790.850947742397
# resampling since: 6338.945884004527
# resampling since: 6578.505408457274
# resampling since: 6104.888671136966
# resampling since: 6285.18452727429
# resampling since: 4958.602756558054
# resampling since: 6164.183658336129
# resampling since: 5950.884758393724
# resampling since: 5705.285150095012
# resampling since: 4738.235990376973
# resampling since: 6441.805358245117
# resampling since: 5805.541691117787
# resampling since: 5065.300903025446
# resampling since: 1281.5058145940686
# resampling since: 6110.8393570747285
# resampling since: 5098.359320217815
# resampling since: 6004.430924296024
# resampling since: 6326.088257308125
# resampling since: 6918.7338659364705
# resampling since: 6344.341556105659
# resampling since: 2189.272437576668
# resampling since: 6591.008556814109
# resampling since: 6721.005085577984
# resampling since: 6780.122319616636
# resampling since: 5642.293431523341
# resampling since: 5835.133045352159
# resampling since: 1954.3752221306206
# resampling since: 3981.355773020738
# resampling since: 6807.706924857264
# resampling since: 4402.773348405936
# resampling since: 6715.709608651446
# resampling since: 6505.085178517589
# resampling since: 4255.794473773164
# resampling since: 6408.756519411972
# resampling since: 4224.664719219372
# resampling since: 6441.837541805524
# resampling since: 6587.7012711160305
# resampling since: 5185.620841490531
# resampling since: 5655.290549154047
# resampling since: 6865.941690828707
# resampling since: 4802.929288848238
# resampling since: 6564.3654463339335
# resampling since: 6372.6702711214175
# resampling since: 6347.988796736705
# resampling since: 6761.64762047892
# resampling since: 6027.066078579289
# resampling since: 5992.082229673429
# resampling since: 6909.917199896081
# resampling since: 6656.608599974513
# resampling since: 6009.74843245783
# resampling since: 5927.277102157641
# resampling since: 6414.273671644451
# resampling since: 2417.1189490034208
# resampling since: 6456.831891904236
# resampling since: 6918.608254733016
# resampling since: 4310.472062967418
# resampling since: 5684.019597366633
# resampling since: 3736.9757324361726
# resampling since: 6002.337833618263
# resampling since: 5423.22494819088
# resampling since: 6621.37230928929
# resampling since: 4356.39803922186
# resampling since: 6003.429555412394
# resampling since: 6185.558236144139
# resampling since: 6604.933803859955
# resampling since: 6367.324664617034
# resampling since: 5915.237488525755
# resampling since: 5732.029737362145
# resampling since: 5836.2105277814235
# resampling since: 4067.7432213185666
# resampling since: 5946.318257378362
# resampling since: 6674.583215198664
# resampling since: 5830.18193000007
# resampling since: 4549.44514389969
# resampling since: 6622.143287877161
# resampling since: 5702.4652772478685
# resampling since: 3088.6880848975657
# resampling since: 5453.197766973163
# resampling since: 6722.849665193879
# resampling since: 5771.320472115552
# resampling since: 5978.132796178448
# resampling since: 6779.459786302122
# resampling since: 5884.144655353016
# resampling since: 6407.772522570361
# resampling since: 5022.104063660553
# resampling since: 6989.883058031234
# resampling since: 3932.629269928674
# resampling since: 6930.467107549058
# resampling since: 6638.504601262437
# resampling since: 6182.0568546354225
# resampling since: 5430.396622079123
# resampling since: 6773.600959811482
# resampling since: 6792.662640289322
# resampling since: 4677.3143100373045
# resampling since: 6918.8767019922225
# resampling since: 5005.222713134314
# resampling since: 6018.89734298966
# resampling since: 4370.091650274078
# resampling since: 4674.879973414913
# resampling since: 3722.216271008937
# resampling since: 6937.80274037767
# resampling since: 6117.932587506449
# resampling since: 3686.7056224566845
# resampling since: 6458.838874438415
# resampling since: 5401.003735341886
# resampling since: 6750.082545649831
# resampling since: 6663.229147782697
# resampling since: 6277.595968550413
# resampling since: 5826.320844663697
# resampling since: 4939.440118523397
# resampling since: 5576.046866869855
# resampling since: 4192.687014403274
# resampling since: 6019.632340087943
# resampling since: 6528.116089960116
# resampling since: 6255.024490603657
# resampling since: 1436.7045181127778
# resampling since: 5188.614041144259
# resampling since: 6774.157977876329
# resampling since: 6578.619398557102
# resampling since: 5579.223468078343
# resampling since: 5135.578506608677
# resampling since: 6310.75954313782
# resampling since: 4014.1990763966896
# resampling since: 765.617726474113
# resampling since: 5545.371545150841
# resampling since: 6196.726346608132
# resampling since: 5753.532958128142
# resampling since: 1914.332753702213
# resampling since: 6032.520943908326
# resampling since: 4631.463647784146
# resampling since: 5638.743751366428
# resampling since: 958.8503767698603
# resampling since: 6020.290608176231
# resampling since: 4329.392686725615
# resampling since: 6729.719368989585
# resampling since: 3750.238762267844
# resampling since: 5164.375375111815
# resampling since: 6785.954652058449
# resampling since: 6664.612333435265
# resampling since: 3865.1159479541725
# resampling since: 6631.689865814617
# resampling since: 6997.244145055251
# resampling since: 6168.961637401254
# resampling since: 6178.7706264557355
# resampling since: 4820.14866637273
# resampling since: 4293.665468662605
# resampling since: 4817.489415222748
# resampling since: 6577.496391238625
# resampling since: 6971.691727421884
# resampling since: 6270.90111545742
# resampling since: 6450.88401159299
# resampling since: 6209.30597701645
# resampling since: 4950.595575840483
# resampling since: 2429.7191702818004
# resampling since: 6096.832602868379
# resampling since: 2445.2103115982927
# resampling since: 6114.0142253814065
# resampling since: 5500.174243255562
# resampling since: 5319.675778070664
# resampling since: 3703.129638895411
# resampling since: 6796.3879164886175

# %%
V_pf_train_daily = V_pf_train / 400
V_pf_test_daily = V_pf_test / 400

# %% [markdown]
# ### Realized GARCH

# %%
# Fit the model
model = RealizedGARCH(p=1, q=1)
model.fit(train_returns, train_RV)

# Get fitted volatility (in-sample)
fitted_vol = model.get_fitted_volatility(train_returns, train_RV)

# Predict volatility (out-of-sample)
predicted_vol = model.predict(test_returns, test_RV)

# %% [markdown]
# ## Plot

# %%
v_item = 'V_pred'

titles_all = ["BOTH Measurements", "RETURNS Measurement", "Heston Particle Filter", "Realized GARCH"]
labels_all = ["Kalman BOTH", "Kalman RETURNS", "Kalman BOTH Corr", "Kalman RETURNS Corr", "PF Heston", "Realized GARCH"]
train_all = [train_result_both_corr[v_item], train_result_returns_corr[v_item], V_pf_train_daily, fitted_vol]
test_all = [test_result_both_corr[v_item], test_result_returns_corr[v_item], V_pf_test_daily, predicted_vol]

Utility.plot_all_filters(
    titles=titles_all,
    labels=labels_all,
    train_filtered_list=train_all,
    test_filtered_list=test_all,
    daily_true_V=daily_true_V,
    daily_RV=daily_RV,
    daily_returns=daily_returns,
    split_index=split_index,
    burnin=252, 
    save_path=r"./output/no_leverage.png"
)

# %%
def qlike_loss(true_var, pred_var):
    y = np.asarray(true_var)
    h = np.asarray(pred_var)
    
    eps = np.finfo(float).eps
    ratio = y / (h + eps)
    return np.mean(ratio - np.log(ratio) - 1)

model_names = ['RV-QLKF', 'QLKF', 'PF', 'Realized GARCH']
true_variances   = daily_true_V[split_index:]
true_volatilities = np.sqrt(true_variances)

mae_scores   = {}
rmse_scores  = {}
qlike_scores = {}

for name, pred_var in zip(model_names, np.array(test_all).clip(1e-9, None)):
    pred_vol = np.sqrt(pred_var)
    
    mae_scores[name]   = mean_absolute_error(true_volatilities, pred_vol)
    rmse_scores[name]  = np.sqrt(mean_squared_error(true_volatilities, pred_vol))
    qlike_scores[name] = qlike_loss(true_variances, pred_var)

print("Results:")
for name in model_names:
    print(f"{name:18s} RMSE: {rmse_scores[name]:.6f}, "
          f"QLIKE: {qlike_scores[name]:.6f}")
# Out:
# Results:
# RV-QLKF            RMSE: 0.001314, QLIKE: 0.021870
# QLKF               RMSE: 0.003235, QLIKE: 0.125327
# PF                 RMSE: 0.002370, QLIKE: 0.064063
# Realized GARCH     RMSE: 0.002497, QLIKE: 0.054356

# %%
data = {}

data['RV-QLKF'] = dict(zip(
    ['kappa', 'theta', 'xi', 'mu', 'sigma', 'rho'],
    [*(params_opt_both_corr[:-1] * 252), params_opt_both_corr[-1]]
))

data['QLKF'] = dict(zip(
    ['kappa', 'theta', 'xi', 'mu', 'rho'],
    [*(params_opt_returns_corr[:-1] * 252), params_opt_returns_corr[-1]]
))
data['QLKF']['sigma'] = np.nan

pf_vals = estimated_param[:, -1]
data['PF'] = {
    'kappa': pf_vals[1],
    'theta': pf_vals[2],
    'xi':    pf_vals[3],
    'mu':    pf_vals[0],
    'rho':   pf_vals[4],
    'sigma': np.nan
}

cols = ['kappa', 'theta', 'xi', 'mu', 'sigma', 'rho']
df_params = pd.DataFrame.from_dict(data, orient='index')[cols]

df_params.T
# Out:
#         RV-QLKF      QLKF        PF
# kappa  2.476305  6.242858  1.547549
# theta  0.036516  0.039585  0.024781
# xi     0.246767  0.000253  0.288326
# mu     0.094836  0.066600  0.077646
# sigma  0.000252       NaN       NaN
# rho   -0.000256  0.001173 -0.361959

# %%
pd.Series(dict(zip(model.param_names[:-1], np.round(model.params[:-1], 4))))
# Out:
# omega      0.0096
# beta       0.7851
# gamma      0.2069
# xi        -0.5014
# phi        0.9330
# tau_1      0.0771
# tau_2      0.0008
# sigma_u    0.2427
# dtype: float64

# %%
# Apply the same preprocessing: fix negatives and compute loss matrices
corrected_preds = []
mse_matrix = []
qlike_matrix = []

def qlike(true_var, pred_var):
    y = np.asarray(true_var)
    h = np.asarray(pred_var)
    
    eps = np.finfo(float).eps
    ratio = y / (h + eps)
    return ratio - np.log(ratio) - 1

for forecast in test_all:
    pred_var = np.array(forecast)

    # Fix negative variances
    neg_mask = pred_var < 0
    pred_var[neg_mask] = true_variances[neg_mask]

    # Compute predicted vol
    pred_vol = np.sqrt(pred_var)

    # Store for matrix stacking
    mse_matrix.append((true_volatilities - pred_vol)**2)
    qlike_matrix.append(qlike(true_variances, pred_var))

# Stack as columns: shape (T, num_models)
mse_matrix = np.column_stack(mse_matrix)
qlike_matrix = np.column_stack(qlike_matrix)

# Initialize and compute Model Confidence Set (MCS)
from model_confidence_set import ModelConfidenceSet

mcs_mse_90 = ModelConfidenceSet(mse_matrix, n_boot=10000, alpha=0.10, show_progress=True)
mcs_qlike_90 = ModelConfidenceSet(qlike_matrix, n_boot=10000, alpha=0.10, show_progress=True)

mcs_mse_75 = ModelConfidenceSet(mse_matrix, n_boot=10000, alpha=0.25, show_progress=True)
mcs_qlike_75 = ModelConfidenceSet(qlike_matrix, n_boot=10000, alpha=0.25, show_progress=True)

mcs_mse_90.compute()
mcs_qlike_90.compute()

mcs_mse_75.compute()
mcs_qlike_75.compute()

mcs_mse_results_90 = mcs_mse_90.results()
mcs_qlike_results_90 = mcs_qlike_90.results()

mcs_mse_results_75 = mcs_mse_75.results()
mcs_qlike_results_75 = mcs_qlike_75.results()
# Out:
# Bootstrapping: 100%|██████████| 10000/10000 [00:00<00:00, 21088.65it/s]
# Computing MCS: 100%|██████████| 3/3 [00:00<00:00, 582.52model/s]
# Bootstrapping: 100%|██████████| 10000/10000 [00:00<00:00, 19859.51it/s]
# Computing MCS: 100%|██████████| 3/3 [00:00<00:00, 664.29model/s]
# Bootstrapping: 100%|██████████| 10000/10000 [00:00<00:00, 21430.57it/s]
# Computing MCS: 100%|██████████| 3/3 [00:00<00:00, 846.93model/s]
# Bootstrapping: 100%|██████████| 10000/10000 [00:00<00:00, 21415.27it/s]
# Computing MCS: 100%|██████████| 3/3 [00:00<00:00, 859.55model/s]

# %%
mcs_mse_results_90
# Out:
#         pvalues    status
# models
# 2        0.0000  excluded
# 4        0.0000  excluded
# 3        0.0003  excluded
# 1        1.0000  included

# %%
mcs_qlike_results_90
# Out:
#         pvalues    status
# models
# 2           0.0  excluded
# 3           0.0  excluded
# 4           0.0  excluded
# 1           1.0  included

# %%
mcs_mse_results_75
# Out:
#         pvalues    status
# models
# 2        0.0000  excluded
# 4        0.0000  excluded
# 3        0.0001  excluded
# 1        1.0000  included

# %%
mcs_qlike_results_75
# Out:
#         pvalues    status
# models
# 2           0.0  excluded
# 3           0.0  excluded
# 4           0.0  excluded
# 1           1.0  included
